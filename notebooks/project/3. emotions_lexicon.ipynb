# %% [markdown]
# # Lexique des émotions

# %% [markdown]
# #### Chargement des bibliothèques

# %%
import os
import json
import spacy
import csv
import numpy as np
import re
from collections import Counter
from collections import defaultdict
from pprint import pprint
import matplotlib.pyplot as plt
import pandas as pd


nlp = spacy.load('fr_core_news_lg')

# %% [markdown]
# #### Chargement du fichier source

# %%
csv_original = "./lexique/FEEL.csv"

# Charger les données à partir du fichier CSV dans un DataFrame
df = pd.read_csv(csv_original, delimiter=";", index_col=0)

df.head(1590)
# Out:
#                                    word  polarity  joy  fear  sadness  anger  \
# id
# 1                       à ce endroit là  positive    0     0        0      0
# 2                             à le hâte  negative    0     1        0      0
# 3                                à part  negative    0     0        1      0
# 4                                 à pic  negative    0     1        0      0
# 5                            à rallonge  negative    0     0        1      0
# ...                                 ...       ...  ...   ...      ...    ...
# 1586                         bon gorgée  negative    0     0        0      0
# 1587                     école maternel  positive    0     0        0      0
# 1588  un foi|fois tout le deux moi|mois  positive    0     0        0      0
# 1589                        @card@ kilo  positive    0     0        0      0
# 1590                   à base de plante  positive    0     0        0      0
#
#       surprise  disgust
# id
# 1            0        0
# 2            1        0
# 3            0        0
# 4            0        0
# 5            0        0
# ...        ...      ...
# 1586         0        1
# 1587         0        0
# 1588         0        0
# 1589         0        0
# 1590         0        0
#
# [1590 rows x 8 columns]

# %%
len(df)
# Out:
# 14127

# %%
# Sélectionner les colonnes d'intérêt pour les émotions
emotions_df = df.iloc[:, 1:] 

# Créer une matrice 8x8 remplie de zéros
matrix = pd.DataFrame(0, index=emotions_df.columns, columns=emotions_df.columns)

# Parcourir les termes et mettre à jour la matrice avec les occurrences des paires émotion-polarité
for term, row in emotions_df.iterrows():
    for emotion1 in emotions_df.columns:
        if row[emotion1] != 0:
            for emotion2 in emotions_df.columns:
                if row[emotion2] != 0:
                    matrix.loc[emotion1, emotion2] += 1

# Affichage de la matrice
display(matrix)
# Out:
#           polarity  joy  fear  sadness  anger  surprise  disgust
# polarity     14127  521  3199     2512   2103      1182     2013
# joy            521  521     0        0      0         0        0
# fear          3199    0  3199     1532   1335       657      909
# sadness       2512    0  1532     2512    932       291      836
# anger         2103    0  1335      932   2103       355      889
# surprise      1182    0   657      291    355      1182      133
# disgust       2013    0   909      836    889       133     2013

# %% [markdown]
# #### Split du champ ``polarity``

# %%
# Traitement de la polarité
polarity_path = "./lexique/emotion_dictionary.csv"

with open(csv_original, 'r', encoding='utf-8') as file:
    csv_reader = csv.DictReader(file, delimiter=';')
    
    with open(polarity_path, 'w', encoding='utf-8', newline='') as out_file:
        fieldnames = ['word', 'positive', 'negative', 'joy', 'fear', 'sadness', 'anger', 'surprise', 'disgust']
        csv_writer = csv.DictWriter(out_file, fieldnames=fieldnames, delimiter=';')
        csv_writer.writeheader()
        
        for row in csv_reader:
            word = row['word']
            polarity = row['polarity']
            emotions = [int(row['joy']), int(row['fear']), int(row['sadness']),
                        int(row['anger']), int(row['surprise']), int(row['disgust'])]
            
            positive = 1 if polarity == 'positive' else 0
            negative = 1 if polarity == 'negative' else 0
            
            csv_writer.writerow({
                'word': word,
                'positive': positive,
                'negative': negative,
                'joy': emotions[0],
                'fear': emotions[1],
                'sadness': emotions[2],
                'anger': emotions[3],
                'surprise': emotions[4],
                'disgust': emotions[5]
            })

# %%
csv_clean = "./lexique/emotion_dictionary.csv"

# Charger les données à partir du fichier CSV dans un DataFrame
df = pd.read_csv(csv_clean, delimiter=";", index_col=0)

# Sélectionner les colonnes d'intérêt pour les émotions en utilisant l'index numérique
emotions_df = df.iloc[:, 0:]  # Ici, nous supposons que les colonnes d'intérêt commencent à l'index 1 (positivity) jusqu'à la fin

# Créer une matrice 8x8 remplie de zéros
matrix = pd.DataFrame(0, index=emotions_df.columns, columns=emotions_df.columns)

# Parcourir les termes et mettre à jour la matrice avec les occurrences des paires émotion-polarité
for term, row in emotions_df.iterrows():
    for emotion1 in emotions_df.columns:
        if row[emotion1] != 0:
            for emotion2 in emotions_df.columns:
                if row[emotion2] != 0:
                    matrix.loc[emotion1, emotion2] += 1

# Affichage de la matrice
display(matrix)
# Out:
#           positive  negative  joy  fear  sadness  anger  surprise  disgust
# positive      8423         0  514   223      131    120       435       91
# negative         0      5704    7  2976     2381   1983       747     1922
# joy            514         7  521     0        0      0         0        0
# fear           223      2976    0  3199     1532   1335       657      909
# sadness        131      2381    0  1532     2512    932       291      836
# anger          120      1983    0  1335      932   2103       355      889
# surprise       435       747    0   657      291    355      1182      133
# disgust         91      1922    0   909      836    889       133     2013

# %% [markdown]
# #### Nettoyage "automatique" du lexique

# %%
polarity_path = "./lexique/emotion_dictionary.csv"
clean_path = "./lexique/emotion_dictionary_clean.csv"

modified_rows = []
modified_words = []  # Liste pour stocker les mots modifiés

with open(polarity_path, 'r', encoding='utf-8') as file:
    csv_reader = csv.DictReader(file, delimiter=';')
    
    for row in csv_reader:
        word = row['word']
        original_word = word
        word = word.replace("?", "oe")
        word = re.sub(r"\bl ", "l'", word)
        word = re.sub(r"\bd ", "d'", word)
        word = re.sub(r"\bs ", "s'", word)
        word = word.replace(" qch", "")
        word = word.replace(" qqn", "")
        word = word.replace("Ã¯", "ï")
        word = word.replace("Ã»", "û")
        word_parts = [part.split('|')[1] if '|' in part else part for part in word.split()]
        new_word = ' '.join(word_parts)
        row['word'] = new_word
        modified_rows.append(row)

        if original_word != new_word:
            modified_words.append({'original_word': original_word, 'modified_word': new_word})

with open(clean_path, 'w', encoding='utf-8', newline='') as file:
    fieldnames = csv_reader.fieldnames
    csv_writer = csv.DictWriter(file, delimiter=';', fieldnames=fieldnames)
    csv_writer.writeheader()
    csv_writer.writerows(modified_rows)

# Afficher le nombre de modifications
nb_modifications = len(modified_words)
print(f"Nombre de modifications : {nb_modifications}")
print("--------------------")

# Afficher les mots modifiés
for modified_word in modified_words:
    print(f"Mot d'origine : {modified_word['original_word']}")
    print(f"Mot modifié : {modified_word['modified_word']}")
    print("--------------------")
# Out:
# Nombre de modifications : 294
# --------------------
# Mot d'origine : coiffeur|coiffeuse
# Mot modifié : coiffeuse
# --------------------
# Mot d'origine : décombre|décombres
# Mot modifié : décombres
# --------------------
# Mot d'origine : dégoÃ»ter
# Mot modifié : dégoûter
# --------------------
# Mot d'origine : directeur|directrice de le photographie
# Mot modifié : directrice de le photographie
# --------------------
# Mot d'origine : dormeur|dormeuse
# Mot modifié : dormeuse
# --------------------
# Mot d'origine : du moi|mois précédent
# Mot modifié : du mois précédent
# --------------------
# Mot d'origine : effrayer|effrayer
# Mot modifié : effrayer
# --------------------
# Mot d'origine : empaqueteur|empaqueteuse
# Mot modifié : empaqueteuse
# --------------------
# Mot d'origine : environ|environs
# Mot modifié : environs
# --------------------
# Mot d'origine : folle|fou
# Mot modifié : fou
# --------------------
# Mot d'origine : folle|fou de joie
# Mot modifié : fou de joie
# --------------------
# Mot d'origine : folle|fou furieux
# Mot modifié : fou furieux
# --------------------
# Mot d'origine : fruit de l imagination
# Mot modifié : fruit de l'imagination
# --------------------
# Mot d'origine : fumeur|fumeuse
# Mot modifié : fumeuse
# --------------------
# Mot d'origine : générateur|génératrice
# Mot modifié : génératrice
# --------------------
# Mot d'origine : graisseur|graisseux
# Mot modifié : graisseux
# --------------------
# Mot d'origine : imaginatif|imaginative
# Mot modifié : imaginative
# --------------------
# Mot d'origine : immortel|immortelle
# Mot modifié : immortelle
# --------------------
# Mot d'origine : inconnu|inconnue
# Mot modifié : inconnue
# --------------------
# Mot d'origine : laineur|laineuse
# Mot modifié : laineuse
# --------------------
# Mot d'origine : martyr|martyre
# Mot modifié : martyre
# --------------------
# Mot d'origine : médiateur|médiatrice
# Mot modifié : médiatrice
# --------------------
# Mot d'origine : meurtrier|meurtrière
# Mot modifié : meurtrière
# --------------------
# Mot d'origine : muet|muette
# Mot modifié : muette
# --------------------
# Mot d'origine : nouveau venu|venue
# Mot modifié : nouveau venue
# --------------------
# Mot d'origine : orphelin|orpheline
# Mot modifié : orpheline
# --------------------
# Mot d'origine : ottoman|ottomane
# Mot modifié : ottomane
# --------------------
# Mot d'origine : patron|patronne
# Mot modifié : patronne
# --------------------
# Mot d'origine : perforateur|perforatrice
# Mot modifié : perforatrice
# --------------------
# Mot d'origine : pierreuse|pierreux
# Mot modifié : pierreux
# --------------------
# Mot d'origine : reproducteur|reproductrice
# Mot modifié : reproductrice
# --------------------
# Mot d'origine : tireur|tireuse
# Mot modifié : tireuse
# --------------------
# Mot d'origine : travailleur|travailleuse
# Mot modifié : travailleuse
# --------------------
# Mot d'origine : tuteur|tutrice
# Mot modifié : tutrice
# --------------------
# Mot d'origine : un foi|fois par semaine
# Mot modifié : un fois par semaine
# --------------------
# Mot d'origine : vérificateur|vérificatrice
# Mot modifié : vérificatrice
# --------------------
# Mot d'origine : violet|violette
# Mot modifié : violette
# --------------------
# Mot d'origine : v?u
# Mot modifié : voeu
# --------------------
# Mot d'origine : un foi|fois tout le deux moi|mois
# Mot modifié : un fois tout le deux mois
# --------------------
# Mot d'origine : à contrec?ur
# Mot modifié : à contrecoeur
# --------------------
# Mot d'origine : à force de qch
# Mot modifié : à force de
# --------------------
# Mot d'origine : à l étranger
# Mot modifié : à l'étranger
# --------------------
# Mot d'origine : à l improviste
# Mot modifié : à l'improviste
# --------------------
# Mot d'origine : à l unanimité
# Mot modifié : à l'unanimité
# --------------------
# Mot d'origine : à spiral|spirale
# Mot modifié : à spirale
# --------------------
# Mot d'origine : accroire|accroître
# Mot modifié : accroître
# --------------------
# Mot d'origine : administrer qch à qqn
# Mot modifié : administrer à
# --------------------
# Mot d'origine : ado|ados
# Mot modifié : ados
# --------------------
# Mot d'origine : âme s?ur
# Mot modifié : âme soeur
# --------------------
# Mot d'origine : aoÃ»t
# Mot modifié : août
# --------------------
# Mot d'origine : archaÃ¯que
# Mot modifié : archaïque
# --------------------
# Mot d'origine : arrière goÃ»t
# Mot modifié : arrière goût
# --------------------
# Mot d'origine : arrivé|arrivée
# Mot modifié : arrivée
# --------------------
# Mot d'origine : au goÃ»t de beurre
# Mot modifié : au goût de beurre
# --------------------
# Mot d'origine : au m?urs léger
# Mot modifié : au moeurs léger
# --------------------
# Mot d'origine : baÃ¯onnette
# Mot modifié : baïonnette
# --------------------
# Mot d'origine : bague|bagues orthodontique
# Mot modifié : bagues orthodontique
# --------------------
# Mot d'origine : bai|baie
# Mot modifié : baie
# --------------------
# Mot d'origine : bailleur de fond|fonds
# Mot modifié : bailleur de fonds
# --------------------
# Mot d'origine : balayer|balayer
# Mot modifié : balayer
# --------------------
# Mot d'origine : bander le ?il
# Mot modifié : bander le oeil
# --------------------
# Mot d'origine : bas fond|fonds
# Mot modifié : bas fonds
# --------------------
# Mot d'origine : bégayer|bégayer
# Mot modifié : bégayer
# --------------------
# Mot d'origine : blond|blonde
# Mot modifié : blonde
# --------------------
# Mot d'origine : bordeau|bordeaux
# Mot modifié : bordeaux
# --------------------
# Mot d'origine : boucler d oreille
# Mot modifié : boucler d'oreille
# --------------------
# Mot d'origine : brÃ»lé
# Mot modifié : brûlé
# --------------------
# Mot d'origine : brÃ»lée
# Mot modifié : brûlée
# --------------------
# Mot d'origine : bruir|bruire de tambour
# Mot modifié : bruire de tambour
# --------------------
# Mot d'origine : bruir|bruire métallique
# Mot modifié : bruire métallique
# --------------------
# Mot d'origine : bruir|bruire sec
# Mot modifié : bruire sec
# --------------------
# Mot d'origine : bruir|bruire sourd
# Mot modifié : bruire sourd
# --------------------
# Mot d'origine : brûlure d estomac
# Mot modifié : brûlure d'estomac
# --------------------
# Mot d'origine : brun|brune
# Mot modifié : brune
# --------------------
# Mot d'origine : calculateur|calculatrice
# Mot modifié : calculatrice
# --------------------
# Mot d'origine : chanter en ch?ur
# Mot modifié : chanter en choeur
# --------------------
# Mot d'origine : charger qqn de faire qch
# Mot modifié : charger de faire
# --------------------
# Mot d'origine : chat|chatte
# Mot modifié : chatte
# --------------------
# Mot d'origine : chaud|chaude
# Mot modifié : chaude
# --------------------
# Mot d'origine : chef d équipe
# Mot modifié : chef d'équipe
# --------------------
# Mot d'origine : chef d orchestre
# Mot modifié : chef d'orchestre
# --------------------
# Mot d'origine : chien|chienne
# Mot modifié : chienne
# --------------------
# Mot d'origine : ch?ur
# Mot modifié : choeur
# --------------------
# Mot d'origine : clignement du ?il
# Mot modifié : clignement du oeil
# --------------------
# Mot d'origine : cligner du ?il
# Mot modifié : cligner du oeil
# --------------------
# Mot d'origine : coÃ¯ncidence
# Mot modifié : coïncidence
# --------------------
# Mot d'origine : cocaÃ¯ne
# Mot modifié : cocaïne
# --------------------
# Mot d'origine : c?ur
# Mot modifié : coeur
# --------------------
# Mot d'origine : commun|communs
# Mot modifié : communs
# --------------------
# Mot d'origine : coup d état
# Mot modifié : coup d'état
# --------------------
# Mot d'origine : courir d air
# Mot modifié : courir d'air
# --------------------
# Mot d'origine : cour|cours
# Mot modifié : cours
# --------------------
# Mot d'origine : cour|cours d eau
# Mot modifié : cours d'eau
# --------------------
# Mot d'origine : croquant|croquante
# Mot modifié : croquante
# --------------------
# Mot d'origine : cuisinier|cuisinière
# Mot modifié : cuisinière
# --------------------
# Mot d'origine : cuit|cuite
# Mot modifié : cuite
# --------------------
# Mot d'origine : d accord
# Mot modifié : d'accord
# --------------------
# Mot d'origine : d actualité
# Mot modifié : d'actualité
# --------------------
# Mot d'origine : d essai
# Mot modifié : d'essai
# --------------------
# Mot d'origine : d humeur changeant
# Mot modifié : d'humeur changeant
# --------------------
# Mot d'origine : d intérieur
# Mot modifié : d'intérieur
# --------------------
# Mot d'origine : d occasion
# Mot modifié : d'occasion
# --------------------
# Mot d'origine : d or
# Mot modifié : d'or
# --------------------
# Mot d'origine : dans le sen|sens de le longueur
# Mot modifié : dans le sens de le longueur
# --------------------
# Mot d'origine : de bon c?ur
# Mot modifié : de bon coeur
# --------------------
# Mot d'origine : déblayer|déblayer
# Mot modifié : déblayer
# --------------------
# Mot d'origine : débrayer|débrayer
# Mot modifié : débrayer
# --------------------
# Mot d'origine : dégoÃ»t
# Mot modifié : dégoût
# --------------------
# Mot d'origine : dégoÃ»tant
# Mot modifié : dégoûtant
# --------------------
# Mot d'origine : demi|demie
# Mot modifié : demie
# --------------------
# Mot d'origine : demoiselle d honneur
# Mot modifié : demoiselle d'honneur
# --------------------
# Mot d'origine : dépeigner|dépeindre
# Mot modifié : dépeindre
# --------------------
# Mot d'origine : dépourvu de qch
# Mot modifié : dépourvu de
# --------------------
# Mot d'origine : dépourvu de sen|sens
# Mot modifié : dépourvu de sens
# --------------------
# Mot d'origine : dépourvue de sen|sens
# Mot modifié : dépourvue de sens
# --------------------
# Mot d'origine : dépourvues de sen|sens
# Mot modifié : dépourvues de sens
# --------------------
# Mot d'origine : dépouvus de sen|sens
# Mot modifié : dépouvus de sens
# --------------------
# Mot d'origine : du tas de qch
# Mot modifié : du tas de
# --------------------
# Mot d'origine : détournement de fond|fonds
# Mot modifié : détournement de fonds
# --------------------
# Mot d'origine : directeur|directrice
# Mot modifié : directrice
# --------------------
# Mot d'origine : donner qch à qqn
# Mot modifié : donner à
# --------------------
# Mot d'origine : donner du cour|cours particulier
# Mot modifié : donner du cours particulier
# --------------------
# Mot d'origine : droit d auteur
# Mot modifié : droit d'auteur
# --------------------
# Mot d'origine : droit|droite
# Mot modifié : droite
# --------------------
# Mot d'origine : du moi|mois dernier
# Mot modifié : du mois dernier
# --------------------
# Mot d'origine : échec|échecs
# Mot modifié : échecs
# --------------------
# Mot d'origine : éc?urer
# Mot modifié : écoeurer
# --------------------
# Mot d'origine : éc?urant
# Mot modifié : écoeurant
# --------------------
# Mot d'origine : éc?urement
# Mot modifié : écoeurement
# --------------------
# Mot d'origine : en cour|cours
# Mot modifié : en cours
# --------------------
# Mot d'origine : en pleur|pleurs
# Mot modifié : en pleurs
# --------------------
# Mot d'origine : en vouloir à qqn
# Mot modifié : en vouloir à
# --------------------
# Mot d'origine : épar|épars
# Mot modifié : épars
# --------------------
# Mot d'origine : essayer|essayer
# Mot modifié : essayer
# --------------------
# Mot d'origine : étayer|étayer
# Mot modifié : étayer
# --------------------
# Mot d'origine : faire de l exercice
# Mot modifié : faire de l'exercice
# --------------------
# Mot d'origine : feu d artifice
# Mot modifié : feu d'artifice
# --------------------
# Mot d'origine : fil|fils
# Mot modifié : fils
# --------------------
# Mot d'origine : flatter qqn servilement
# Mot modifié : flatter servilement
# --------------------
# Mot d'origine : flou|flous
# Mot modifié : flous
# --------------------
# Mot d'origine : foi|fois
# Mot modifié : fois
# --------------------
# Mot d'origine : fond|fonds
# Mot modifié : fonds
# --------------------
# Mot d'origine : fou folle|fou
# Mot modifié : fou fou
# --------------------
# Mot d'origine : général|générale
# Mot modifié : générale
# --------------------
# Mot d'origine : goûteur|goûteux
# Mot modifié : goûteux
# --------------------
# Mot d'origine : gris|grise
# Mot modifié : grise
# --------------------
# Mot d'origine : gueule|gueules
# Mot modifié : gueules
# --------------------
# Mot d'origine : haussement d épaule
# Mot modifié : haussement d'épaule
# --------------------
# Mot d'origine : haut le c?ur
# Mot modifié : haut le coeur
# --------------------
# Mot d'origine : héroÃ¯ne
# Mot modifié : héroïne
# --------------------
# Mot d'origine : héroÃ¯que
# Mot modifié : héroïque
# --------------------
# Mot d'origine : héro|héros
# Mot modifié : héros
# --------------------
# Mot d'origine : homme d état
# Mot modifié : homme d'état
# --------------------
# Mot d'origine : impatient|impatiente
# Mot modifié : impatiente
# --------------------
# Mot d'origine : intendant|intendante
# Mot modifié : intendante
# --------------------
# Mot d'origine : jambier|jambière
# Mot modifié : jambière
# --------------------
# Mot d'origine : jambier|jambière de cuir
# Mot modifié : jambière de cuir
# --------------------
# Mot d'origine : jardin d enfant
# Mot modifié : jardin d'enfant
# --------------------
# Mot d'origine : jar|jars
# Mot modifié : jars
# --------------------
# Mot d'origine : jeÃ»ne
# Mot modifié : jeûne
# --------------------
# Mot d'origine : jeter un coup d ?il
# Mot modifié : jeter un coup d'oeil
# --------------------
# Mot d'origine : jeu d argent
# Mot modifié : jeu d'argent
# --------------------
# Mot d'origine : joyeuses|joyeux
# Mot modifié : joyeux
# --------------------
# Mot d'origine : kiosque à journal|journau
# Mot modifié : kiosque à journau
# --------------------
# Mot d'origine : laitier|laitière
# Mot modifié : laitière
# --------------------
# Mot d'origine : le ?il bandé
# Mot modifié : le oeil bandé
# --------------------
# Mot d'origine : limbe|limbes
# Mot modifié : limbes
# --------------------
# Mot d'origine : lire d enfant
# Mot modifié : lire d'enfant
# --------------------
# Mot d'origine : lunette|lunettes
# Mot modifié : lunettes
# --------------------
# Mot d'origine : lunette|lunettes de protection
# Mot modifié : lunettes de protection
# --------------------
# Mot d'origine : lunette|lunettes de soleil
# Mot modifié : lunettes de soleil
# --------------------
# Mot d'origine : maintes foi|fois
# Mot modifié : maintes fois
# --------------------
# Mot d'origine : mal à l aise
# Mot modifié : mal à l'aise
# --------------------
# Mot d'origine : malais|malaise
# Mot modifié : malaise
# --------------------
# Mot d'origine : maline|malines
# Mot modifié : malines
# --------------------
# Mot d'origine : man?uvrer
# Mot modifié : manoeuvrer
# --------------------
# Mot d'origine : man?uvre
# Mot modifié : manoeuvre
# --------------------
# Mot d'origine : marge de man?uvre
# Mot modifié : marge de manoeuvre
# --------------------
# Mot d'origine : matériau|matériaux
# Mot modifié : matériaux
# --------------------
# Mot d'origine : méridien|méridienne
# Mot modifié : méridienne
# --------------------
# Mot d'origine : mettre au défi de faire qch
# Mot modifié : mettre au défi de faire
# --------------------
# Mot d'origine : mettre l accent sur
# Mot modifié : mettre l'accent sur
# --------------------
# Mot d'origine : milieu de l être
# Mot modifié : milieu de l'être
# --------------------
# Mot d'origine : mettre en ?uvre
# Mot modifié : mettre en oeuvre
# --------------------
# Mot d'origine : moi|mois
# Mot modifié : mois
# --------------------
# Mot d'origine : national|nationaux
# Mot modifié : nationaux
# --------------------
# Mot d'origine : ne pas être d accord
# Mot modifié : ne pas être d'accord
# --------------------
# Mot d'origine : négatif|négative
# Mot modifié : négative
# --------------------
# Mot d'origine : n?ud coulant
# Mot modifié : noeud coulant
# --------------------
# Mot d'origine : noir|noire
# Mot modifié : noire
# --------------------
# Mot d'origine : non sen|sens
# Mot modifié : non sens
# --------------------
# Mot d'origine : ?cuménique
# Mot modifié : oecuménique
# --------------------
# Mot d'origine : ?il
# Mot modifié : oeil
# --------------------
# Mot d'origine : ?illet
# Mot modifié : oeillet
# --------------------
# Mot d'origine : ?uf
# Mot modifié : oeuf
# --------------------
# Mot d'origine : ?uf de poisson
# Mot modifié : oeuf de poisson
# --------------------
# Mot d'origine : ?uvre
# Mot modifié : oeuvre
# --------------------
# Mot d'origine : ?uvre classique
# Mot modifié : oeuvre classique
# --------------------
# Mot d'origine : ouvrer|ouvrir boîte
# Mot modifié : ouvrir boîte
# --------------------
# Mot d'origine : ouvreur|ouvreuse
# Mot modifié : ouvreuse
# --------------------
# Mot d'origine : pagayer|pagayer
# Mot modifié : pagayer
# --------------------
# Mot d'origine : parent|parents
# Mot modifié : parents
# --------------------
# Mot d'origine : payer|payer
# Mot modifié : payer
# --------------------
# Mot d'origine : personne qui changer qch
# Mot modifié : personne qui changer
# --------------------
# Mot d'origine : petit gros petit gros|grosse
# Mot modifié : petit gros petit grosse
# --------------------
# Mot d'origine : planteur|planteuse
# Mot modifié : planteuse
# --------------------
# Mot d'origine : plein d espoir
# Mot modifié : plein d'espoir
# --------------------
# Mot d'origine : pleur|pleurs
# Mot modifié : pleurs
# --------------------
# Mot d'origine : plusieurs foi|fois
# Mot modifié : plusieurs fois
# --------------------
# Mot d'origine : poigner|poindre
# Mot modifié : poindre
# --------------------
# Mot d'origine : poste d amarrage
# Mot modifié : poste d'amarrage
# --------------------
# Mot d'origine : priver de qch
# Mot modifié : priver de
# --------------------
# Mot d'origine : prochain|prochaine
# Mot modifié : prochaine
# --------------------
# Mot d'origine : qui recouvrer|recouvrir
# Mot modifié : qui recouvrir
# --------------------
# Mot d'origine : qui s empiffrer
# Mot modifié : qui s'empiffrer
# --------------------
# Mot d'origine : qui s ennuyer
# Mot modifié : qui s'ennuyer
# --------------------
# Mot d'origine : qui tendre ver|vers
# Mot modifié : qui tendre vers
# --------------------
# Mot d'origine : râleur|râleux
# Mot modifié : râleux
# --------------------
# Mot d'origine : rasseoir|rassir
# Mot modifié : rassir
# --------------------
# Mot d'origine : recouvrer|recouvrir
# Mot modifié : recouvrir
# --------------------
# Mot d'origine : regarder avec du ?il rond
# Mot modifié : regarder avec du oeil rond
# --------------------
# Mot d'origine : relayer|relayer
# Mot modifié : relayer
# --------------------
# Mot d'origine : rétrospectif|rétrospective
# Mot modifié : rétrospective
# --------------------
# Mot d'origine : s abstenir
# Mot modifié : s'abstenir
# --------------------
# Mot d'origine : s accroupir
# Mot modifié : s'accroupir
# --------------------
# Mot d'origine : s adapter
# Mot modifié : s'adapter
# --------------------
# Mot d'origine : s agenouiller
# Mot modifié : s'agenouiller
# --------------------
# Mot d'origine : s armer
# Mot modifié : s'armer
# --------------------
# Mot d'origine : s arrêter
# Mot modifié : s'arrêter
# --------------------
# Mot d'origine : s attarder
# Mot modifié : s'attarder
# --------------------
# Mot d'origine : s attendre à
# Mot modifié : s'attendre à
# --------------------
# Mot d'origine : s atténuer
# Mot modifié : s'atténuer
# --------------------
# Mot d'origine : s attrouper
# Mot modifié : s'attrouper
# --------------------
# Mot d'origine : s avérer
# Mot modifié : s'avérer
# --------------------
# Mot d'origine : s éclairer
# Mot modifié : s'éclairer
# --------------------
# Mot d'origine : s écouler
# Mot modifié : s'écouler
# --------------------
# Mot d'origine : s efforcer
# Mot modifié : s'efforcer
# --------------------
# Mot d'origine : s élever
# Mot modifié : s'élever
# --------------------
# Mot d'origine : s émerveiller
# Mot modifié : s'émerveiller
# --------------------
# Mot d'origine : s emmêler
# Mot modifié : s'emmêler
# --------------------
# Mot d'origine : s emporter
# Mot modifié : s'emporter
# --------------------
# Mot d'origine : s enchevêtrer
# Mot modifié : s'enchevêtrer
# --------------------
# Mot d'origine : s endurcir
# Mot modifié : s'endurcir
# --------------------
# Mot d'origine : s enrager
# Mot modifié : s'enrager
# --------------------
# Mot d'origine : s ensuivre
# Mot modifié : s'ensuivre
# --------------------
# Mot d'origine : s entraînant
# Mot modifié : s'entraînant
# --------------------
# Mot d'origine : s envaser
# Mot modifié : s'envaser
# --------------------
# Mot d'origine : s épanouir
# Mot modifié : s'épanouir
# --------------------
# Mot d'origine : s éparpiller
# Mot modifié : s'éparpiller
# --------------------
# Mot d'origine : s estomper
# Mot modifié : s'estomper
# --------------------
# Mot d'origine : s étendre
# Mot modifié : s'étendre
# --------------------
# Mot d'origine : s évertuer
# Mot modifié : s'évertuer
# --------------------
# Mot d'origine : s exécutant
# Mot modifié : s'exécutant
# --------------------
# Mot d'origine : s expatrier
# Mot modifié : s'expatrier
# --------------------
# Mot d'origine : s identifier
# Mot modifié : s'identifier
# --------------------
# Mot d'origine : s inclinant
# Mot modifié : s'inclinant
# --------------------
# Mot d'origine : s incliner
# Mot modifié : s'incliner
# --------------------
# Mot d'origine : s inquiéter
# Mot modifié : s'inquiéter
# --------------------
# Mot d'origine : s inscrire
# Mot modifié : s'inscrire
# --------------------
# Mot d'origine : s occupant de
# Mot modifié : s'occupant de
# --------------------
# Mot d'origine : s opposer à
# Mot modifié : s'opposer à
# --------------------
# Mot d'origine : sableur|sableuse
# Mot modifié : sableuse
# --------------------
# Mot d'origine : sailler|saillir
# Mot modifié : saillir
# --------------------
# Mot d'origine : salin|saline
# Mot modifié : saline
# --------------------
# Mot d'origine : sans c?ur
# Mot modifié : sans coeur
# --------------------
# Mot d'origine : se battre pour qch
# Mot modifié : se battre pour
# --------------------
# Mot d'origine : se retourner contre qqn
# Mot modifié : se retourner contre
# --------------------
# Mot d'origine : sen|sens
# Mot modifié : sens
# --------------------
# Mot d'origine : sen|sens général
# Mot modifié : sens général
# --------------------
# Mot d'origine : serre|serres
# Mot modifié : serres
# --------------------
# Mot d'origine : s?ur
# Mot modifié : soeur
# --------------------
# Mot d'origine : sortir avec qqn
# Mot modifié : sortir avec
# --------------------
# Mot d'origine : sou payer|payer
# Mot modifié : sou payer
# --------------------
# Mot d'origine : spiral|spirale
# Mot modifié : spirale
# --------------------
# Mot d'origine : suivant|suivante
# Mot modifié : suivante
# --------------------
# Mot d'origine : supporter qch
# Mot modifié : supporter
# --------------------
# Mot d'origine : surpayer|surpayer
# Mot modifié : surpayer
# --------------------
# Mot d'origine : suturer qch
# Mot modifié : suturer
# --------------------
# Mot d'origine : taie d oreiller
# Mot modifié : taie d'oreiller
# --------------------
# Mot d'origine : tau|taux
# Mot modifié : taux
# --------------------
# Mot d'origine : tête de n?ud
# Mot modifié : tête de noeud
# --------------------
# Mot d'origine : tir à l arc
# Mot modifié : tir à l'arc
# --------------------
# Mot d'origine : tondeur|tondeuse
# Mot modifié : tondeuse
# --------------------
# Mot d'origine : tourbier|tourbière
# Mot modifié : tourbière
# --------------------
# Mot d'origine : traire d union
# Mot modifié : traire d'union
# --------------------
# Mot d'origine : trois foi|fois
# Mot modifié : trois fois
# --------------------
# Mot d'origine : trop payer|payer
# Mot modifié : trop payer
# --------------------
# Mot d'origine : vers l extérieur
# Mot modifié : vers l'extérieur
# --------------------
# Mot d'origine : vers l intérieur
# Mot modifié : vers l'intérieur
# --------------------
# Mot d'origine : veuf|veuve
# Mot modifié : veuve
# --------------------
# Mot d'origine : virus de l herpès
# Mot modifié : virus de l'herpès
# --------------------
# Mot d'origine : vivre|vivres
# Mot modifié : vivres
# --------------------
# Mot d'origine : voÃ»te
# Mot modifié : voûte
# --------------------
# Mot d'origine : vol à l étalage
# Mot modifié : vol à l'étalage
# --------------------

# %%
# Compter le nombre de lignes dans le fichier CSV original
with open(polarity_path, 'r', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    num_lines_polarity = len(list(csv_reader)) - 1

# Compter le nombre de lignes dans le fichier CSV nettoyé
with open(clean_path, 'r', encoding='utf-8') as file:
    csv_reader = csv.reader(file)
    num_lines_clean = len(list(csv_reader)) - 1

# Afficher le nombre de lignes
print("Nombre de lignes :", num_lines_polarity)
print("Nombre de lignes dans le fichier traité :", num_lines_clean)
# Out:
# Nombre de lignes : 14127
# Nombre de lignes dans le fichier traité : 14127

# %%
def load_csv_content(csv_path):
    csv_content = []
    with open(csv_path, newline='', encoding='utf-8') as csvfile:
        csv_reader = csv.DictReader(csvfile, delimiter=';')
        for row in csv_reader:
            word = row['word']
            polarity = np.array([int(row['positive']), int(row['negative'])])
            emotions = np.array([int(row['joy']), int(row['fear']), int(row['sadness']),
                                 int(row['anger']), int(row['surprise']), int(row['disgust'])])
            csv_content.append({'word': word, 'polarity': polarity, 'emotions': emotions})
    return csv_content

# %%
def load_dictionary(csv_path):
    emotion_dict = {}

    with open(csv_path, newline='', encoding='utf-8') as csvfile:
        csv_reader = csv.DictReader(csvfile, delimiter=';')
        for row in csv_reader:
            word = row['word']
            polarity = np.array([int(row['positive']), int(row['negative'])])
            emotions = np.array([int(row['joy']), int(row['fear']), int(row['sadness']),
                                 int(row['anger']), int(row['surprise']), int(row['disgust'])])

            if word in emotion_dict:
                # Fusionner les vecteurs d'émotions des doublons en prenant la valeur maximale
                emotion_dict[word]['polarity'] = np.maximum(emotion_dict[word]['polarity'], polarity)
                emotion_dict[word]['emotions'] = np.maximum(emotion_dict[word]['emotions'], emotions)
            else:
                emotion_dict[word] = {'polarity': polarity, 'emotions': emotions}

    return emotion_dict

# %% [markdown]
# #### Correction manuelle

# %%
polarity_path = "./lexique/emotion_dictionary.csv"
clean_path = "./lexique/emotion_dictionary_clean.csv"
manual_path = "./lexique/emotion_dictionary_clean_manual.csv"

# Comptage des lignes du CSV
csv_polarity = load_csv_content(polarity_path)
csv_clean = load_csv_content(clean_path)
csv_manual = load_csv_content(manual_path)

num_csv_polarity = len(csv_polarity)
num_csv_clean = len(csv_clean)
num_csv_manual = len(csv_manual)

# Comptage des clés du dictionnaire
dict_polarity = load_dictionary(polarity_path) 
dict_clean = load_dictionary(clean_path)
dict_manual = load_dictionary(manual_path)

num_dict_polarity = len(dict_polarity)
num_dict_clean = len(dict_clean)
num_dict_manual = len(dict_manual)

print("Nombre de lignes (sans les en-têtes) :")
print("---------------------")
print(f"CSV - Gestion des polarité : {num_csv_polarity}")
print(f"CSV - Nettoyage automatique : {num_csv_clean}")
print(f"CSV - Nettoyage manuel : {num_csv_manual}")
print("---------------------")
print(f"Dictionnaire - Gestion des polarités : {num_dict_polarity}")
print(f"Dictionnaire - Nettoyage automatique : {num_dict_clean}")
print(f"Dictionnaire - Nettoyage manuel : {num_dict_manual}")
# Out:
# Nombre de lignes (sans les en-têtes) :
# ---------------------
# CSV - Gestion des polarité : 14127
# CSV - Nettoyage automatique : 14127
# CSV - Nettoyage manuel : 14127
# ---------------------
# Dictionnaire - Gestion des polarités : 14126
# Dictionnaire - Nettoyage automatique : 14110
# Dictionnaire - Nettoyage manuel : 14072

# %%
def find_duplicates(csv_file):
    duplicates = {}
    for entry in csv_file:
        word = entry['word']
        if word in duplicates:
            duplicates[word]['polarity'].append(entry['polarity'])
            duplicates[word]['emotions'].append(entry['emotions'])
        else:
            duplicates[word] = {'polarity': [entry['polarity']], 'emotions': [entry['emotions']]}
    return duplicates

# %%
# Charger le fichier CSV
manual_path = "./lexique/emotion_dictionary_clean_manual.csv"

csv_manual = load_csv_content(manual_path)

# Trouver les doublons dans le dictionnaire
duplicates = find_duplicates(csv_manual)

for word, values in duplicates.items():
    if len(values['polarity']) > 1:
        print("---------------------")
        print("'"+ word + "'")
        print("---------------------")
        for i in range(len(values['polarity'])):
            print("Polarité :", values['polarity'][i])
            print("Vecteur d'émotions :", values['emotions'][i])
# Out:
# ---------------------
# 'acclamer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 1 0]
# ---------------------
# 'accroître'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'bien'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 1 0 0 1 0]
# ---------------------
# 'défloration'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'dégoût'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 1]
# ---------------------
# 'dégoûtant'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 1]
# ---------------------
# 'dégoûter'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 1]
# ---------------------
# 'dépeindre'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'écho'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'éclaircir'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# ---------------------
# 'éclipse'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# ---------------------
# 'économie'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 1]
# ---------------------
# 'éditeur'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'éditorial'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'éleveur'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'émeraude'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'éminence'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'émir'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'épars'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# ---------------------
# 'éphéméride'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'évanescence'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 1 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 1 0]
# ---------------------
# 'évolution'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'fou de joie'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 1 0]
# ---------------------
# 'fou furieux'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 1]
# ---------------------
# 'goûteux'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# ---------------------
# 'grâce'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'graisseux'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 1]
# ---------------------
# 'hémi'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'héroïque'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 1 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 1 0]
# ---------------------
# 'hétérogénéité'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'impérial'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'infidèle'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# ---------------------
# 'intégral'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'joyeux'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 1 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'juvénile'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'médias'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'mémorial'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'observant'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'peu commun'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'pierreux'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# ---------------------
# 'recouvrir'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'régent'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'répudiation'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 1 0 1]
# ---------------------
# 'restreindre'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# ---------------------
# 'réunion'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'supplier'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# ---------------------
# 'supporter'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'téflon'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'télescope'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'Traductions'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'véga'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'vertébral'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'voûte'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 1 1 0 0 0]
# ---------------------
# 'zéphyr'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]

# %% [markdown]
# #### Vérification des doublons après lemmatisation du dictionnaire

# %%
def tokenize_and_lemmatize(text):
    doc = nlp(text)
    tokens = [token.lemma_.lower() for token in doc if not token.is_punct]
    return tokens

# %%
manual_path = "./lexique/emotion_dictionary_clean_manual.csv"
lemma_path = "./lexique/emotion_dictionary_lemmatized.csv"

def write_lemmatized_dictionary(emotion_dict_path, output_file):
    with open(emotion_dict_path, newline='', encoding='utf-8') as csvfile, open(output_file, 'w', newline='', encoding='utf-8') as outfile:
        csv_reader = csv.DictReader(csvfile, delimiter=';')
        fieldnames = csv_reader.fieldnames
        csv_writer = csv.DictWriter(outfile, delimiter=';', fieldnames=fieldnames)
        csv_writer.writeheader()

        for row in csv_reader:
            word = row['word']
            lemmatized_words = tokenize_and_lemmatize(word.lower())
            lemmatized_expression = ' '.join(lemmatized_words)
            row['word'] = lemmatized_expression
            csv_writer.writerow(row)

# Écriture du dictionnaire d'émotions lemmatisé dans un fichier de sortie
write_lemmatized_dictionary(manual_path, lemma_path)

# %%
polarity_path = "./lexique/emotion_dictionary.csv"
clean_path = "./lexique/emotion_dictionary_clean.csv"
manual_path = "./lexique/emotion_dictionary_clean_manual.csv"
lemma_path = "./lexique/emotion_dictionary_lemmatized.csv"

# Comptage des lignes du CSV
csv_polarity = load_csv_content(polarity_path)
csv_clean = load_csv_content(clean_path)
csv_manual = load_csv_content(manual_path)
csv_lemma = load_csv_content(lemma_path)

num_csv_polarity = len(csv_polarity)
num_csv_clean = len(csv_clean)
num_csv_manual = len(csv_manual)
num_csv_lemma = len(csv_lemma)

# Comptage des clés du dictionnaire
dict_polarity = load_dictionary(polarity_path) 
dict_clean = load_dictionary(clean_path)
dict_manual = load_dictionary(manual_path)
dict_lemma = load_dictionary(lemma_path)

num_dict_polarity = len(dict_polarity)
num_dict_clean = len(dict_clean)
num_dict_manual = len(dict_manual)
num_dict_lemma = len(dict_lemma)

print("Nombre de lignes (sans les en-têtes) :")
print("---------------------")
print(f"CSV - Gestion des polarités : {num_csv_polarity}")
print(f"CSV - Nettoyage automatique : {num_csv_clean}")
print(f"CSV - Nettoyage manuel : {num_csv_manual}")
print(f"CSV - Lemmatisation spaCy : {num_csv_lemma}")
print("---------------------")
print(f"Dictionnaire - Gestion des polarités : {num_dict_polarity}")
print(f"Dictionnaire - Nettoyage automatique : {num_dict_clean}")
print(f"Dictionnaire - Nettoyage manuel : {num_dict_manual}")
print(f"Dictionnaire - Lemmatisation spaCy : {num_dict_lemma}")
# Out:
# Nombre de lignes (sans les en-têtes) :
# ---------------------
# CSV - Gestion des polarités : 14127
# CSV - Nettoyage automatique : 14127
# CSV - Nettoyage manuel : 14127
# CSV - Lemmatisation spaCy : 14125
# ---------------------
# Dictionnaire - Gestion des polarités : 14126
# Dictionnaire - Nettoyage automatique : 14110
# Dictionnaire - Nettoyage manuel : 14072
# Dictionnaire - Lemmatisation spaCy : 13658

# %% [markdown]
# Attention, à ce stade, les deux mots "avoir" (venant de "aura" et "as") ont supprimés manuellement.

# %%
# Trouver les doublons dans le dictionnaire
duplicates = find_duplicates(csv_lemma)

# Imprimer les doublons et leurs vecteurs correspondants
for word, values in duplicates.items():
    if len(values['polarity']) > 1:
        print("---------------------")
        print("'" + word + "'")
        print("---------------------")
        for i in range(len(values['polarity'])):
            print("Polarité :", values['polarity'][i])
            print("Vecteur d'émotions :", values['emotions'][i])
# Out:
# ---------------------
# 'abandonner'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# ---------------------
# 'abattre'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 1 0]
# ---------------------
# 'abîmer'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 0]
# ---------------------
# 'absorber'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 1 0]
# ---------------------
# 'acclamer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 1 0]
# ---------------------
# 'accepter'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'accroître'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'adoucir'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'affaisser'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# ---------------------
# 'affuter'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# ---------------------
# 'agressif'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 0]
# ---------------------
# 'aimer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'amatrice'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'ambassadeur'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'ambigu'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# ---------------------
# 'améliorer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'amorcer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'amphibien'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 1]
# ---------------------
# 'anesthésier'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# ---------------------
# 'annoncer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'apaiser'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'appeler'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'apprendre'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 1 0]
# ---------------------
# 'approprier'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'arrêter'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 1 0]
# ---------------------
# 'artisan'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'aspirer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'assaillir'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# ---------------------
# 'assourdir'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 1 0]
# ---------------------
# 'astral'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'attacher'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'attenir'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'attentionner'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'avancer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 1 0 0 1 0]
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# ---------------------
# 'aveugler'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 1 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 1 0]
# ---------------------
# 'barbu'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'bas'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 0]
# ---------------------
# 'battre'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 0]
# ---------------------
# 'bénin'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# ---------------------
# 'bien'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 1 0 0 1 0]
# ---------------------
# 'blaguer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 1 0]
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# ---------------------
# 'blesser'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# ---------------------
# 'bond'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# ---------------------
# 'border'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'boréal'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'boucher'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 1 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 1]
# ---------------------
# 'bouleverser'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 0]
# ---------------------
# 'branler'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 1 0]
# ---------------------
# 'bref'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'brûler'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 0]
# ---------------------
# 'brut'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# ---------------------
# 'caduc'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 1]
# ---------------------
# 'capital'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'casser'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 1 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 1 0]
# ---------------------
# 'céder'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'célébrer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# ---------------------
# 'central'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'chacun'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'champion'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# ---------------------
# 'chanceler'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 1 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 1 0]
# ---------------------
# 'changer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 1 0 0 0 0]
# ---------------------
# 'chaud'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 1 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 1 0 0]
# ---------------------
# 'cher'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# ---------------------
# 'choral'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'cingler'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 1 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 1 1]
# ---------------------
# 'clair'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'clignoter'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 1 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'coïncider'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'colorer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'commun'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'compatir'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 1 1 0 0 0]
# ---------------------
# 'compatissant'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 1 1 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 1 1 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 1 1 0 0 0]
# ---------------------
# 'condescendre'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 1]
# ---------------------
# 'confier'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'conjonctif'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'conquérir'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# ---------------------
# 'consentir'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'constituer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 1 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'contigu'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'contributeur'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'converger'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'coopérer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'coopératif'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'correspondre'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'corrosif'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 1]
# ---------------------
# 'côtier'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'coucher de soleil'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'courant'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'couvrir'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'croire'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'croiser'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'croître'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'croquant'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'cueillir'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# ---------------------
# 'cuire'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'dangereux'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 1 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 1 0]
# ---------------------
# 'de gouverneur'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'débuter'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'décimal'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'décolorer'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 1]
# ---------------------
# 'décourager'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# ---------------------
# 'défectueux'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 1]
# ---------------------
# 'défloration'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'dégoût'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 1]
# ---------------------
# 'dégoûtant'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 1]
# ---------------------
# 'dégoûter'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 1]
# ---------------------
# 'dégrader'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 1]
# ---------------------
# 'délictuel'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 1 0 1]
# ---------------------
# 'dépasser'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 1 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 1]
# ---------------------
# 'dépeindre'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'dépendre'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'déplaire'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 1]
# ---------------------
# 'dépourvu'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# ---------------------
# 'dépourvu de sens'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# ---------------------
# 'dépressif'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# ---------------------
# 'déprimer'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 0]
# ---------------------
# 'dérouter'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 1 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 1 0]
# ---------------------
# 'désinfecter'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 1]
# ---------------------
# 'désobéir'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 0]
# ---------------------
# 'désobliger'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# ---------------------
# 'dessinateur'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'détectable'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'devoir'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'discorder'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# ---------------------
# 'dissiper'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'dissoudre'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'diverger'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 1 1 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'dominant'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# ---------------------
# 'donner'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'dormeur'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'dubitatif'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# ---------------------
# 'échec'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 1]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'écho'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'éclaircir'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# ---------------------
# 'éclipse'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# ---------------------
# 'écoeurer'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# ---------------------
# 'économie'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 1]
# ---------------------
# 'écraser'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# ---------------------
# 'écrire'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'éditeur'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'éditorial'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'efféminer'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'élever'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'éleveur'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'embarrassant'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# ---------------------
# 'émeraude'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'éminence'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'émir'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'empereur'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'empêtrer'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# ---------------------
# 'enquêteur'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'entraîner'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'entrer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'entreprendre'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'envahir'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 1 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 1 1]
# ---------------------
# 'environ'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'épars'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# ---------------------
# 'éphémérid'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'éprouver'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# ---------------------
# 'épuiser'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# ---------------------
# 'errer'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# ---------------------
# 'estival'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# ---------------------
# 'établir'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'étouffer'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 1 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 0]
# ---------------------
# 'évanescence'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 1 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 1 0]
# ---------------------
# 'évident'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 1 0 1]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'évolution'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'exiger'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 1 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 1 0 0]
# ---------------------
# 'exister'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'exposer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 1 0]
# ---------------------
# 'extraordinaire'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 1 0 0 1 0]
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# ---------------------
# 'fallacieux'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 1 0 1]
# ---------------------
# 'fasciner'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 1 0 0 1 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 1 0 0 1 0]
# ---------------------
# 'fermer'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 1]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'figurer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'flou'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# ---------------------
# 'fluo'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'fondre'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'fou de joie'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 1 0]
# ---------------------
# 'fou furieux'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 1]
# ---------------------
# 'fourmiller'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 0]
# ---------------------
# 'frapper'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 1 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 1 0]
# ---------------------
# 'frissonner'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# ---------------------
# 'fulgurer'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 1 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 1 0]
# ---------------------
# 'gagner'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 1 0]
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# ---------------------
# 'galvaniser'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# ---------------------
# 'garer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'gardien'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 0]
# ---------------------
# 'gay'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# ---------------------
# 'gazeux'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 1]
# ---------------------
# 'géant'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# ---------------------
# 'gêner'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# ---------------------
# 'général'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'glacial'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# ---------------------
# 'glisser'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'gluer'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 1]
# ---------------------
# 'goudronneux'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 1]
# ---------------------
# 'goûteux'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# ---------------------
# 'gouverner'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'grâce'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'graisseu'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 1]
# ---------------------
# 'grelotter'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# ---------------------
# 'gris'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 1]
# ---------------------
# 'grouiller'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 1]
# ---------------------
# 'gueule'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 1]
# ---------------------
# 'hâter'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 1 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 1 0]
# ---------------------
# 'hémi'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'héroïque'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 1 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 1 0]
# ---------------------
# 'hésiter'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# ---------------------
# 'hétérogénéité'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'humilier'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 1]
# ---------------------
# 'hygiénique'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'ignorer'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 1]
# ---------------------
# 'imaginatif'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'immortel'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'impatient'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 1 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 1 0 0]
# ---------------------
# 'impérial'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'inapproprié'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 1 0 1]
# ---------------------
# 'inclure'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'inconnu'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# ---------------------
# 'indifférenciable'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'indifférent'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 1 0 1]
# ---------------------
# 'individuel'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# ---------------------
# 'infecter'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 1]
# ---------------------
# 'infidèle'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# ---------------------
# 'innommable'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# ---------------------
# 'inoffensif'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'insulter'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 1 1 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# ---------------------
# 'intégral'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'irriter'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 1 0 1]
# ---------------------
# 'joyeux'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 1 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'jumeau'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'juvénile'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'laineux'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'laitier'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'languir'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# ---------------------
# 'lent'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 1]
# ---------------------
# 'loger'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'lointain'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# ---------------------
# 'long'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'lourd'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 1 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 0]
# ---------------------
# 'lunette'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'monsieur'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'maline'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'malveillant'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 1 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 1 0 0]
# ---------------------
# 'manifester'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'manuel'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'maussade'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 1 0 0]
# ---------------------
# 'média'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'mémorial'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# ---------------------
# 'menacer'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 1]
# ---------------------
# 'méridien'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'mériter'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'mettre fin'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# ---------------------
# 'monumental'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'mouvementer'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 0]
# ---------------------
# 'muet'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 1 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 1 0]
# ---------------------
# 'mûr'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'naître'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# ---------------------
# 'national'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'nébuleux'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# ---------------------
# 'négatif'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# ---------------------
# 'négliger'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# ---------------------
# 'négligent'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 0]
# ---------------------
# 'nègre'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 1 0 0]
# ---------------------
# 'net'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'noir'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# ---------------------
# 'nominer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'non armer'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'non découvrir'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 1 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 1 0]
# ---------------------
# 'non former'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# ---------------------
# 'nourrir'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 1 0 0 0]
# ---------------------
# 'nouveau venir'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 1 0 0 1 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 1 0 0 1 0]
# ---------------------
# 'nuageux'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# ---------------------
# 'obéir'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 1 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'observer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'occuper'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 1 0 0]
# ---------------------
# 'offenser'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# ---------------------
# 'officier'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'officieux'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# ---------------------
# 'offrir'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# ---------------------
# 'opposer'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# ---------------------
# 'oppressant'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# ---------------------
# 'orphelin'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# ---------------------
# 'osciller'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# ---------------------
# 'ouvrir'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'payer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'parent'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'parental'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'particulier'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 1 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'passionner'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 1 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 1 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'peindre'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'pénétrer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 1 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 1 0]
# ---------------------
# 'perdre'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 1 1 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 1 0]
# ---------------------
# ...
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'réfléchir'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'refroidir'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'refuser'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 1 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'régent'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'régler'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 1 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'régner'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'régulier'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'renard'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'renommer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'reposer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'repousser'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 1]
# ---------------------
# 'reproducteur'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# ---------------------
# 'répudiation'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 1 0 1]
# ---------------------
# 'répugner'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 1]
# ---------------------
# 'requérir'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 1 0 1]
# ---------------------
# 'résistant'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# ---------------------
# 'respectueux'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'resplendir'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# ---------------------
# 'ressembler'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'rester'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'restaurer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'restreindre'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# ---------------------
# 'retentir'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 1 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 1 0]
# ---------------------
# 'réunion'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'réussir'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# ---------------------
# 'révolter'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 1]
# ---------------------
# 'rond'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'rotatif'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'rougir'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 1 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 1 0]
# ---------------------
# 'royal'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'ruisseler'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'sacrer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'salin'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'salir'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# ---------------------
# 'sangler'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# ---------------------
# 'sanguin'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'sec'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 1 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 1 0]
# ---------------------
# 'secret'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 1 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# ---------------------
# 'séduire'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'sembler'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'séparer'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# ---------------------
# 'serre'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 0]
# ---------------------
# 'siffler'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 1 0]
# ---------------------
# 'se incliner'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 1 0 0 0 0]
# ---------------------
# 'songer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# ---------------------
# 'sortir'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 1 0 0 1 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'souffler'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 1 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# ---------------------
# 'souffrir'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 1]
# ---------------------
# 'soupirer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 1 0 1]
# ---------------------
# 'sourire'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [1 0 0 0 0 0]
# ---------------------
# 'soutenir'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'souterrain'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# ---------------------
# 'stagner'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# ---------------------
# 'stimuler'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'suivre'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'supplier'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# ---------------------
# 'supporter'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'surfacturer'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# ---------------------
# 'surnager'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'surplomber'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'surveiller'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 1 0 0 0 0]
# ---------------------
# 'surveiller pénitentiaire'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 0]
# ---------------------
# 'tailler'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# ---------------------
# 'téflon'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'télescope'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'tenter'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 1 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 1 0]
# ---------------------
# 'textural'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'tirer'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 1 1 1 1 0]
# ---------------------
# 'tomber'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 0 0 0]
# ---------------------
# 'toucher'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 1 0 0 0]
# ---------------------
# 'tournant'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 0 0]
# ---------------------
# 'tracasser'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 0]
# ---------------------
# 'traduction'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'transversal'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'traumatiser'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 1 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 1 0]
# ---------------------
# 'travailleur'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'tremblant'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 1 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 1 1 0 0]
# ---------------------
# 'tremper'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 1]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 1]
# ---------------------
# 'très long'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'trésorier'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'trieur'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'trop long'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# ---------------------
# 'tuteur'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'ultraviolet'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'urbain'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'user'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 0 1 0 0 0]
# ---------------------
# 'véger'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'verdoyer'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'vertébral'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'vigiler'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 1 0 1 1 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 1 0 1 1 0]
# ---------------------
# 'vilain'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 1 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 1 0]
# ---------------------
# 'vital'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'vivre'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'volant'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 1 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 1 0 0 0 0]
# ---------------------
# 'voter'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 1 1 1 0]
# ---------------------
# 'voûte'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 1 1 0 0 0]
# ---------------------
# 'zéphyr'
# ---------------------
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# Polarité : [1 0]
# Vecteur d'émotions : [0 0 0 0 0 0]
# ---------------------
# 'zinzin'
# ---------------------
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 1 0]
# Polarité : [0 1]
# Vecteur d'émotions : [0 1 0 0 1 0]

# %%
dict_lemma = load_dictionary(lemma_path)

pprint(dict_lemma)
# Out:
# {'@card@ kilo': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'abaissement': {'emotions': array([0, 0, 1, 0, 0, 0]),
#                  'polarity': array([0, 1])},
#  'abaisser': {'emotions': array([0, 0, 1, 0, 0, 0]), 'polarity': array([0, 1])},
#  'abandon': {'emotions': array([0, 1, 1, 1, 1, 0]), 'polarity': array([0, 1])},
#  'abandonner': {'emotions': array([0, 1, 1, 1, 0, 1]),
#                 'polarity': array([0, 1])},
#  'abasourdir': {'emotions': array([0, 0, 0, 0, 1, 0]),
#                 'polarity': array([0, 1])},
#  'abattoir': {'emotions': array([0, 1, 1, 1, 0, 1]), 'polarity': array([0, 1])},
#  'abattre': {'emotions': array([0, 1, 1, 1, 1, 1]), 'polarity': array([0, 1])},
#  'abbé': {'emotions': array([0, 1, 0, 0, 0, 0]), 'polarity': array([0, 1])},
#  'abcès': {'emotions': array([0, 1, 1, 0, 0, 1]), 'polarity': array([0, 1])},
#  'abdiquer': {'emotions': array([0, 1, 1, 0, 0, 0]), 'polarity': array([0, 1])},
#  'abdomen': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'abdominal': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'abeille': {'emotions': array([0, 1, 0, 1, 0, 0]), 'polarity': array([0, 1])},
#  'aberrer': {'emotions': array([0, 0, 0, 1, 1, 0]), 'polarity': array([0, 1])},
#  'abhorrer': {'emotions': array([0, 1, 0, 1, 0, 1]), 'polarity': array([0, 1])},
#  'abimé': {'emotions': array([0, 1, 1, 1, 0, 0]), 'polarity': array([0, 1])},
#  'abject': {'emotions': array([0, 0, 0, 1, 0, 1]), 'polarity': array([0, 1])},
#  'ablation': {'emotions': array([0, 1, 0, 0, 0, 1]), 'polarity': array([0, 1])},
#  'aboiement': {'emotions': array([0, 1, 0, 1, 0, 0]),
#                'polarity': array([0, 1])},
#  'abolir': {'emotions': array([0, 0, 1, 1, 0, 0]), 'polarity': array([0, 1])},
#  'abolition': {'emotions': array([0, 0, 1, 1, 0, 0]),
#                'polarity': array([0, 1])},
#  'abominable': {'emotions': array([0, 1, 0, 0, 0, 1]),
#                 'polarity': array([0, 1])},
#  'abomination': {'emotions': array([0, 1, 1, 1, 0, 1]),
#                  'polarity': array([0, 1])},
#  'abondant': {'emotions': array([1, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'abonder': {'emotions': array([1, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'abonnement': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'aborder': {'emotions': array([0, 0, 0, 1, 1, 0]), 'polarity': array([1, 0])},
#  'aborigène': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'abortif': {'emotions': array([0, 1, 1, 1, 0, 0]), 'polarity': array([0, 1])},
#  'aboutir': {'emotions': array([1, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'aboyer': {'emotions': array([0, 1, 0, 1, 0, 0]), 'polarity': array([0, 1])},
#  'abrasion': {'emotions': array([0, 1, 1, 0, 0, 1]), 'polarity': array([0, 1])},
#  'abreuvoir': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'abri de jardin': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                     'polarity': array([0, 1])},
#  'abriter': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'abrogation': {'emotions': array([0, 1, 1, 0, 0, 0]),
#                 'polarity': array([0, 1])},
#  'abroger': {'emotions': array([0, 1, 1, 0, 0, 0]), 'polarity': array([0, 1])},
#  'abrupt': {'emotions': array([0, 1, 0, 0, 0, 0]), 'polarity': array([0, 1])},
#  'abrutir': {'emotions': array([0, 0, 0, 1, 0, 1]), 'polarity': array([0, 1])},
#  'abréger': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'abréviation': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'absence': {'emotions': array([0, 1, 1, 0, 0, 0]), 'polarity': array([0, 1])},
#  'absent': {'emotions': array([0, 1, 1, 0, 0, 0]), 'polarity': array([0, 1])},
#  'absentéisme': {'emotions': array([0, 0, 1, 0, 0, 0]),
#                  'polarity': array([0, 1])},
#  'absinthe': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([0, 1])},
#  'absolution': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'absorber': {'emotions': array([0, 0, 0, 0, 1, 0]), 'polarity': array([1, 0])},
#  'absorption': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'absoudre': {'emotions': array([1, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'abstention': {'emotions': array([0, 1, 1, 0, 0, 0]),
#                 'polarity': array([0, 1])},
#  'abstinence': {'emotions': array([0, 1, 1, 0, 0, 0]),
#                 'polarity': array([0, 1])},
#  'abstraction': {'emotions': array([0, 1, 1, 0, 0, 0]),
#                  'polarity': array([0, 1])},
#  'abstrair': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'absurde': {'emotions': array([0, 0, 0, 1, 1, 1]), 'polarity': array([0, 1])},
#  'absurdité': {'emotions': array([0, 0, 0, 1, 1, 1]),
#                'polarity': array([0, 1])},
#  'abuser de': {'emotions': array([0, 1, 1, 1, 0, 0]),
#                'polarity': array([0, 1])},
#  'abîmer': {'emotions': array([0, 1, 1, 1, 0, 0]), 'polarity': array([0, 1])},
#  'académie': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'académique': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'accablant': {'emotions': array([0, 1, 1, 1, 0, 0]),
#                'polarity': array([0, 1])},
#  'accabler': {'emotions': array([0, 1, 1, 1, 0, 0]), 'polarity': array([0, 1])},
#  'accentuation': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                   'polarity': array([1, 0])},
#  'accentuer': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'acceptable': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'acceptation': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'accepter': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'accessible': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'accession': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'accessoire': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([0, 1])},
#  'accessoirement': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                     'polarity': array([0, 1])},
#  'accident mortel': {'emotions': array([0, 1, 1, 0, 0, 0]),
#                      'polarity': array([0, 1])},
#  'accident vasculaire cérébral': {'emotions': array([0, 1, 1, 0, 1, 0]),
#                                   'polarity': array([0, 1])},
#  'accidentel': {'emotions': array([0, 1, 1, 0, 1, 0]),
#                 'polarity': array([0, 1])},
#  'accidentellement': {'emotions': array([0, 1, 1, 0, 1, 0]),
#                       'polarity': array([0, 1])},
#  'accidenter': {'emotions': array([0, 1, 1, 0, 0, 0]),
#                 'polarity': array([0, 1])},
#  'acclamation': {'emotions': array([1, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'acclamer': {'emotions': array([0, 0, 0, 0, 1, 0]), 'polarity': array([1, 0])},
#  'accolade': {'emotions': array([0, 0, 0, 0, 1, 0]), 'polarity': array([1, 0])},
#  'accommodation': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                    'polarity': array([1, 0])},
#  'accommoder': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'accompagnement': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                     'polarity': array([1, 0])},
#  'accompagner': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'accomplir': {'emotions': array([1, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'accomplissement': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                      'polarity': array([1, 0])},
#  'accord': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'accordable': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'accorder': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'accordéon': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'accoutumer': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'accro': {'emotions': array([0, 0, 1, 1, 0, 0]), 'polarity': array([0, 1])},
#  'accroc': {'emotions': array([0, 1, 0, 0, 1, 0]), 'polarity': array([0, 1])},
#  'accrochage': {'emotions': array([0, 0, 0, 1, 0, 0]),
#                 'polarity': array([0, 1])},
#  'accrocher': {'emotions': array([0, 1, 0, 0, 1, 0]),
#                'polarity': array([0, 1])},
#  'accroire': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'accroissement': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                    'polarity': array([1, 0])},
#  'accroupir': {'emotions': array([0, 1, 0, 0, 0, 0]),
#                'polarity': array([0, 1])},
#  'accroupissement': {'emotions': array([0, 1, 0, 0, 0, 0]),
#                      'polarity': array([0, 1])},
#  'accroître': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'accréditer': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'accueil': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'accueillir': {'emotions': array([1, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'accumuler': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'accusateur': {'emotions': array([0, 1, 0, 1, 0, 1]),
#                 'polarity': array([0, 1])},
#  'accusatif': {'emotions': array([0, 0, 0, 1, 0, 1]),
#                'polarity': array([0, 1])},
#  'accusation': {'emotions': array([0, 0, 0, 1, 0, 1]),
#                 'polarity': array([0, 1])},
#  'accuser': {'emotions': array([0, 1, 1, 1, 0, 1]), 'polarity': array([0, 1])},
#  'accès': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'accéder': {'emotions': array([1, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'accélérateur': {'emotions': array([0, 0, 0, 1, 0, 0]),
#                   'polarity': array([0, 1])},
#  'accélération': {'emotions': array([0, 1, 0, 0, 0, 0]),
#                   'polarity': array([1, 0])},
#  'acharner': {'emotions': array([0, 1, 0, 1, 0, 1]), 'polarity': array([0, 1])},
#  'achat': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'acheminer par pont aérien': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                                'polarity': array([1, 0])},
#  'acheminer par tuyau': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                          'polarity': array([1, 0])},
#  'acheter': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'acheteur': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'achever': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'achèvement': {'emotions': array([1, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'acide': {'emotions': array([0, 0, 0, 0, 0, 1]), 'polarity': array([0, 1])},
#  'acidité': {'emotions': array([0, 0, 0, 0, 0, 1]), 'polarity': array([0, 1])},
#  'acier': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'acompte': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'acouphène': {'emotions': array([0, 1, 1, 0, 0, 0]),
#                'polarity': array([0, 1])},
#  'acoustique': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'acquiescement': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                    'polarity': array([1, 0])},
#  'acquisition': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'acquéreur': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'acquérir': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'acrobate': {'emotions': array([0, 1, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'acte': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'acte de défi': {'emotions': array([0, 1, 0, 1, 0, 1]),
#                   'polarity': array([0, 1])},
#  'acte de fiducie': {'emotions': array([0, 0, 0, 1, 0, 0]),
#                      'polarity': array([0, 1])},
#  'acte délictuel': {'emotions': array([0, 1, 0, 1, 0, 0]),
#                     'polarity': array([0, 1])},
#  'actif': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'action': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'action de grâce': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                      'polarity': array([1, 0])},
#  'actionnable': {'emotions': array([0, 1, 0, 1, 0, 1]),
#                  'polarity': array([0, 1])},
#  'actionnaire': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'active': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'activité': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'actuaire': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'actualité': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'actuel': {'emotions': array([0, 0, 0, 0, 1, 0]), 'polarity': array([1, 0])},
#  'acuité': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'acupuncture': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'acérer': {'emotions': array([0, 1, 0, 1, 0, 0]), 'polarity': array([0, 1])},
#  'acétique': {'emotions': array([0, 0, 0, 0, 0, 1]), 'polarity': array([0, 1])},
#  'adage': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'adaptabiliter': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                    'polarity': array([1, 0])},
#  'adaptable': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'adaptation': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'adapter': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'addenda': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'addiction': {'emotions': array([0, 1, 1, 0, 0, 0]),
#                'polarity': array([0, 1])},
#  'additif': {'emotions': array([0, 0, 0, 0, 0, 1]), 'polarity': array([0, 1])},
#  'addition': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'additionnel': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'additionner': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'adepte': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'adhérence': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'adhérent': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'adhérer': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'adhérer à': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'adhésif': {'emotions': array([0, 0, 0, 0, 0, 1]), 'polarity': array([1, 0])},
#  'adhésion': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'adieu': {'emotions': array([0, 0, 1, 0, 0, 0]), 'polarity': array([0, 1])},
#  'adipeux': {'emotions': array([0, 0, 0, 0, 0, 1]), 'polarity': array([0, 1])},
#  'adjacent': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'adjectif': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'adjectival': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'adjoindre': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'adjuvant': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'admettre': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'administrateur': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                     'polarity': array([1, 0])},
#  'administratif': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                    'polarity': array([1, 0])},
#  'administration': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                     'polarity': array([1, 0])},
#  'administrer': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'administrer à': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                    'polarity': array([1, 0])},
#  'admirable': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'admirateur': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'admiration': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'admirer': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'admissibiliter': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                     'polarity': array([1, 0])},
#  'admissible': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'admission': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'admonition': {'emotions': array([0, 1, 0, 1, 0, 0]),
#                 'polarity': array([0, 1])},
#  'ado': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'adobe': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'adolescence': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'adolescent': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'adopter': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'adoption': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'adorable': {'emotions': array([0, 0, 1, 0, 1, 0]), 'polarity': array([1, 0])},
#  'adoration': {'emotions': array([0, 1, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'adorer': {'emotions': array([0, 1, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'adosser': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'adoucir': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'adoucissement': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                    'polarity': array([1, 0])},
#  'adresse': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'adresser': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'adroit': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'adulte': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'adultère': {'emotions': array([0, 0, 1, 1, 0, 1]), 'polarity': array([0, 1])},
#  'adversair': {'emotions': array([0, 1, 0, 1, 0, 1]),
#                'polarity': array([0, 1])},
#  'adverse': {'emotions': array([0, 1, 0, 1, 0, 1]), 'polarity': array([0, 1])},
#  'adversité': {'emotions': array([0, 1, 1, 1, 0, 0]),
#                'polarity': array([0, 1])},
#  'adéquat': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'adéquation': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'affable': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'affaiblir': {'emotions': array([0, 1, 1, 0, 0, 0]),
#                'polarity': array([0, 1])},
#  'affaire': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'affairement': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'affaissement': {'emotions': array([0, 0, 1, 0, 0, 0]),
#                   'polarity': array([0, 1])},
#  'affaisser': {'emotions': array([0, 0, 1, 0, 0, 0]),
#                'polarity': array([0, 1])},
#  'affamer': {'emotions': array([0, 1, 1, 1, 0, 0]), 'polarity': array([0, 1])},
#  'affectation': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'affecter': {'emotions': array([0, 0, 1, 0, 0, 0]), 'polarity': array([0, 1])},
#  'affection': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'affectueux': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'affichage': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'affiche': {'emotions': array([0, 0, 0, 0, 1, 0]), 'polarity': array([1, 0])},
#  'afficher': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'affidavit': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'affiliation': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'affilier': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'affinage': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'affiner': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'affinité': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'affirmatif': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'affirmation': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'affirmative': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'affirmativement': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                      'polarity': array([1, 0])},
#  'affirmer': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'affixe': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'affliction': {'emotions': array([0, 1, 1, 0, 0, 1]),
#                 'polarity': array([0, 1])},
#  'affliger': {'emotions': array([0, 1, 1, 0, 0, 0]), 'polarity': array([0, 1])},
#  'affluent': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'affluer': {'emotions': array([0, 1, 0, 1, 1, 0]), 'polarity': array([0, 1])},
#  'afflux': {'emotions': array([0, 1, 0, 0, 1, 0]), 'polarity': array([0, 1])},
#  'affolement': {'emotions': array([0, 1, 0, 1, 0, 0]),
#                 'polarity': array([0, 1])},
#  'affoler': {'emotions': array([0, 1, 1, 0, 0, 0]), 'polarity': array([0, 1])},
#  'affreux': {'emotions': array([0, 1, 1, 1, 1, 1]), 'polarity': array([0, 1])},
#  'affronter': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([0, 1])},
#  'affréter': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'affuter': {'emotions': array([0, 1, 0, 0, 0, 0]), 'polarity': array([0, 1])},
#  'affuté': {'emotions': array([0, 1, 0, 0, 0, 0]), 'polarity': array([0, 1])},
#  'agacement': {'emotions': array([0, 0, 1, 1, 0, 1]),
#                'polarity': array([0, 1])},
#  'agacer': {'emotions': array([0, 0, 1, 1, 0, 0]), 'polarity': array([0, 1])},
#  'agate': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'agence': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'agenouiller': {'emotions': array([0, 0, 1, 0, 0, 0]),
#                  'polarity': array([0, 1])},
#  'agent': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'agent de change': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                      'polarity': array([1, 0])},
#  'agent de conservation': {'emotions': array([0, 0, 0, 0, 1, 0]),
#                            'polarity': array([1, 0])},
#  'agent de police': {'emotions': array([0, 1, 0, 0, 0, 0]),
#                      'polarity': array([1, 0])},
#  'agglomération': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                    'polarity': array([1, 0])},
#  'agglomérer': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([0, 1])},
#  'aggravation': {'emotions': array([0, 1, 1, 1, 0, 1]),
#                  'polarity': array([0, 1])},
#  'aggraver': {'emotions': array([0, 1, 1, 1, 0, 0]), 'polarity': array([0, 1])},
#  'agile': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'agilité': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'agir': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'agissement': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'agiter': {'emotions': array([0, 1, 0, 1, 0, 0]), 'polarity': array([0, 1])},
#  'agneau': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'agnostique': {'emotions': array([0, 1, 1, 0, 0, 0]),
#                 'polarity': array([0, 1])},
#  'agonir': {'emotions': array([0, 1, 1, 1, 0, 0]), 'polarity': array([0, 1])},
#  'agrafe': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'agrafer': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'agrandir': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([0, 1])},
#  'agresseur': {'emotions': array([0, 1, 1, 1, 0, 0]),
#                'polarity': array([0, 1])},
#  'agressif': {'emotions': array([0, 1, 0, 1, 0, 0]), 'polarity': array([0, 1])},
#  'agression': {'emotions': array([0, 1, 0, 1, 1, 0]),
#                'polarity': array([0, 1])},
#  'agricole': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'agriculteur': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'agriculture': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'agréable': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'agrégat': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([0, 1])},
#  'agrégation': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([0, 1])},
#  'ahurir': {'emotions': array([0, 0, 0, 0, 1, 0]), 'polarity': array([0, 1])},
#  'ahurissant': {'emotions': array([0, 0, 0, 0, 1, 0]),
#                 'polarity': array([0, 1])},
#  'aide': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'aider': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'aigle': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'aigre': {'emotions': array([0, 0, 0, 0, 0, 1]), 'polarity': array([0, 1])},
#  'aigue-marine': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                   'polarity': array([1, 0])},
#  'aiguille': {'emotions': array([0, 1, 0, 0, 0, 0]), 'polarity': array([0, 1])},
#  'aiguiller': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'aiguillonner': {'emotions': array([0, 1, 0, 0, 0, 0]),
#                   'polarity': array([1, 0])},
#  'aiguiser': {'emotions': array([0, 1, 0, 1, 0, 0]), 'polarity': array([1, 0])},
#  'aiguisoir': {'emotions': array([0, 1, 0, 0, 0, 0]),
#                'polarity': array([0, 1])},
#  'ail': {'emotions': array([0, 0, 0, 0, 0, 1]), 'polarity': array([0, 1])},
#  'aile': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'ailer': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'aileron': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'aimable': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'aimer': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'air': {'emotions': array([0, 0, 0, 0, 0, 1]), 'polarity': array([0, 1])},
#  'airbag': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'aire': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'aire de jeu': {'emotions': array([0, 0, 0, 0, 1, 0]),
#                  'polarity': array([1, 0])},
#  'aisance': {'emotions': array([1, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'aisé': {'emotions': array([1, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'aisément': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'ajournement': {'emotions': array([0, 0, 1, 0, 0, 0]),
#                  'polarity': array([0, 1])},
#  'ajourner': {'emotions': array([0, 0, 1, 0, 0, 0]), 'polarity': array([0, 1])},
#  'ajout': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'ajouter': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'ajustage': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'ajustement': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'ajuster': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'alambiquer': {'emotions': array([0, 0, 0, 0, 0, 1]),
#                 'polarity': array([0, 1])},
#  'alanguir': {'emotions': array([0, 0, 1, 0, 0, 0]), 'polarity': array([0, 1])},
#  'alarme': {'emotions': array([0, 1, 0, 0, 1, 0]), 'polarity': array([0, 1])},
#  'alarmer': {'emotions': array([0, 1, 0, 0, 1, 0]), 'polarity': array([0, 1])},
#  'album': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'albâtre': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'alcali': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'alcalin': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'alcaloïde': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'alchimie': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'alcool': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([0, 1])},
#  'alcoolisme': {'emotions': array([0, 1, 1, 1, 0, 1]),
#                 'polarity': array([0, 1])},
#  'alcôve': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'alentour': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'alerte': {'emotions': array([0, 1, 0, 1, 1, 0]), 'polarity': array([1, 0])},
#  'algorithme': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'algèbr': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'algébrique': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'alibi': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'alignement': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'aligner': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'aliment': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'alimentaire': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'alimentation': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                   'polarity': array([1, 0])},
#  'alimenter': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'alinéa': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'aliquote': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'aliénation': {'emotions': array([0, 1, 1, 1, 0, 1]),
#                 'polarity': array([0, 1])},
#  'aliéner': {'emotions': array([0, 0, 1, 0, 0, 1]), 'polarity': array([0, 1])},
#  'allaitement': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'allaiter': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'allegro': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'allemand': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'aller': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'aller chercher': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                     'polarity': array([1, 0])},
#  'aller à tout vitesse': {'emotions': array([0, 1, 0, 0, 0, 0]),
#                           'polarity': array([0, 1])},
#  'alliage': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'alliance': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'allier': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'alligator': {'emotions': array([0, 1, 0, 0, 0, 0]),
#                'polarity': array([0, 1])},
#  'allocatair': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'allocation': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'allocation de chômage': {'emotions': array([0, 0, 1, 0, 0, 0]),
#                            'polarity': array([0, 1])},
#  'allocution': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'allongement': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'allonger': {'emotions': array([0, 1, 1, 1, 0, 1]), 'polarity': array([0, 1])},
#  'allouer': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'allumage': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'allumette': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'allure': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'allusion': {'emotions': array([0, 1, 0, 1, 1, 0]), 'polarity': array([0, 1])},
#  'alluvial': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'alléchant': {'emotions': array([0, 0, 0, 0, 1, 0]),
#                'polarity': array([1, 0])},
#  'allécher': {'emotions': array([0, 0, 0, 0, 1, 0]), 'polarity': array([1, 0])},
#  'allégation': {'emotions': array([0, 0, 0, 1, 0, 0]),
#                 'polarity': array([0, 1])},
#  'allégeance': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'allégorie': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'allégorique': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'allégresse': {'emotions': array([1, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'alléguer': {'emotions': array([0, 1, 0, 0, 0, 1]), 'polarity': array([0, 1])},
#  'almanach': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'aloha': {'emotions': array([1, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'alors que': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([0, 1])},
#  'alouette': {'emotions': array([1, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'alphabet': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'alphabétique': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                   'polarity': array([1, 0])},
#  'alpinist': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'altercation': {'emotions': array([0, 0, 0, 1, 0, 0]),
#                  'polarity': array([0, 1])},
#  'alternatif': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'alternative': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'alterner': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'altitude': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'alto': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'altération': {'emotions': array([0, 0, 1, 0, 0, 1]),
#                 'polarity': array([0, 1])},
#  'altérer': {'emotions': array([0, 0, 1, 1, 0, 1]), 'polarity': array([0, 1])},
#  'alvéolaire': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'alésage': {'emotions': array([0, 1, 0, 1, 0, 0]), 'polarity': array([0, 1])},
#  'amadouer': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'amande': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'amant': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'amarrage': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'amarrer': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'amas': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([0, 1])},
#  'amasser': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'amateur': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([0, 1])},
#  'amatrice': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([0, 1])},
#  'ambassade': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'ambassadeur': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'ambiance': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'ambier': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'ambigu': {'emotions': array([0, 1, 0, 0, 0, 0]), 'polarity': array([0, 1])},
#  'ambiguïté': {'emotions': array([0, 1, 0, 0, 0, 0]),
#                'polarity': array([0, 1])},
#  'ambitieux': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'ambition': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'ambre': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'ambrer': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'ambulance': {'emotions': array([0, 1, 1, 0, 0, 0]),
#                'polarity': array([0, 1])},
#  'amen': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'amendement': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'amender': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'amertume': {'emotions': array([0, 0, 1, 1, 0, 1]), 'polarity': array([0, 1])},
#  'ami': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'amical': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'amidon': {'emotions': array([0, 0, 0, 0, 0, 1]), 'polarity': array([0, 1])},
#  'amidonner': {'emotions': array([0, 0, 0, 0, 0, 1]),
#                'polarity': array([0, 1])},
#  'amiral': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'amirauté': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'amitié': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'ammoniac': {'emotions': array([0, 0, 0, 0, 0, 1]), 'polarity': array([0, 1])},
#  'amnistie': {'emotions': array([1, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'amnésie': {'emotions': array([0, 1, 1, 0, 0, 0]), 'polarity': array([0, 1])},
#  'amoindrir': {'emotions': array([0, 0, 1, 0, 0, 0]),
#                'polarity': array([0, 1])},
#  'amorcer': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'amorphe': {'emotions': array([0, 0, 1, 0, 0, 1]), 'polarity': array([0, 1])},
#  'amortir': {'emotions': array([0, 1, 0, 1, 1, 0]), 'polarity': array([0, 1])},
#  'amortisseur': {'emotions': array([0, 1, 0, 0, 0, 0]),
#                  'polarity': array([0, 1])},
#  'amorçage': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'amour': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'amourette': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([0, 1])},
#  'amoureux': {'emotions': array([1, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'amphibie': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'amphibien': {'emotions': array([0, 0, 0, 0, 0, 1]),
#                'polarity': array([0, 1])},
#  'amphithéâtre': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                   'polarity': array([1, 0])},
#  'amphétamine': {'emotions': array([0, 0, 0, 0, 0, 1]),
#                  'polarity': array([0, 1])},
#  'amplement': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'ampleur': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'amplification': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                    'polarity': array([1, 0])},
#  'amplifier': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'amplitude': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'amputation': {'emotions': array([0, 1, 1, 0, 0, 1]),
#                 'polarity': array([0, 1])},
#  'amulette': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'amusant': {'emotions': array([1, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'amusement': {'emotions': array([1, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'amuser': {'emotions': array([1, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'amuser gueule': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                    'polarity': array([1, 0])},
#  'amygdale': {'emotions': array([0, 0, 0, 0, 0, 1]), 'polarity': array([0, 1])},
#  'amèrement': {'emotions': array([0, 0, 1, 1, 0, 1]),
#                'polarity': array([0, 1])},
#  'amélioration': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                   'polarity': array([1, 0])},
#  'améliorer': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'aménagement': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'aménagement paysager': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                           'polarity': array([1, 0])},
#  'aménité': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'améthyste': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'an': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'anaconda': {'emotions': array([0, 1, 0, 0, 0, 1]), 'polarity': array([0, 1])},
#  'anal': {'emotions': array([0, 1, 0, 0, 0, 0]), 'polarity': array([0, 1])},
#  'analgésique': {'emotions': array([0, 1, 0, 0, 0, 0]),
#                  'polarity': array([0, 1])},
#  'analogie': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'analogique': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'analogue': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'analphabète': {'emotions': array([0, 0, 1, 0, 0, 1]),
#                  'polarity': array([0, 1])},
#  'analyse': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'analyser': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'analyseur': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'analyste': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'analytique': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'ananas': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'anarchie': {'emotions': array([0, 1, 0, 1, 0, 0]), 'polarity': array([0, 1])},
#  'anarchisme': {'emotions': array([0, 1, 0, 1, 0, 0]),
#                 'polarity': array([0, 1])},
#  'anarchiste': {'emotions': array([0, 1, 0, 1, 0, 0]),
#                 'polarity': array([0, 1])},
#  'anastomose': {'emotions': array([0, 1, 0, 0, 0, 1]),
#                 'polarity': array([0, 1])},
#  'anathème': {'emotions': array([0, 1, 1, 1, 0, 1]), 'polarity': array([0, 1])},
#  'anatomie': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'anatomique': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'ancestral': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'ancien': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([0, 1])},
#  'ancien combattant': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                        'polarity': array([1, 0])},
#  'ancien élever': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                    'polarity': array([1, 0])},
#  'ancienneté': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'ancrage': {'emotions': array([0, 0, 1, 0, 0, 0]), 'polarity': array([1, 0])},
#  'ancre': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'ancêtre': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'anesthésie': {'emotions': array([0, 1, 0, 0, 0, 0]),
#                 'polarity': array([0, 1])},
#  'anesthésier': {'emotions': array([0, 1, 0, 0, 0, 0]),
#                  'polarity': array([0, 1])},
#  'anesthésique': {'emotions': array([0, 1, 0, 0, 0, 0]),
#                   'polarity': array([0, 1])},
#  'ange': {'emotions': array([0, 0, 0, 0, 1, 0]), 'polarity': array([1, 0])},
#  'angine': {'emotions': array([0, 1, 1, 0, 0, 0]), 'polarity': array([0, 1])},
#  'angiographie': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                   'polarity': array([1, 0])},
#  'angle': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'angoissant': {'emotions': array([0, 1, 1, 0, 0, 0]),
#                 'polarity': array([0, 1])},
#  'angoisse': {'emotions': array([0, 1, 1, 1, 0, 0]), 'polarity': array([0, 1])},
#  'angoisser': {'emotions': array([0, 1, 1, 0, 0, 0]),
#                'polarity': array([0, 1])},
#  'anguille': {'emotions': array([0, 1, 0, 0, 0, 1]), 'polarity': array([0, 1])},
#  'angulaire': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'anguleux': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'angélique': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'anhydre': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'animal': {'emotions': array([0, 1, 0, 0, 0, 1]), 'polarity': array([0, 1])},
#  'animal de compagnie': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                          'polarity': array([0, 1])},
#  'animer': {'emotions': array([1, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'animosité': {'emotions': array([0, 1, 1, 1, 0, 1]),
#                'polarity': array([0, 1])},
#  'annal': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'anneau': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'annexe': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'annexer': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'annexion': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'annihilation': {'emotions': array([0, 1, 1, 1, 0, 0]),
#                   'polarity': array([0, 1])},
#  'annihiler': {'emotions': array([0, 1, 0, 1, 0, 0]),
#                'polarity': array([0, 1])},
#  'anniversaire': {'emotions': array([0, 0, 0, 0, 1, 0]),
#                   'polarity': array([1, 0])},
#  'annoncer': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'annotation': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'annoter': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'annuaire': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'annuel': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'annulaire': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'annulation': {'emotions': array([0, 1, 1, 1, 1, 0]),
#                 'polarity': array([0, 1])},
#  'année': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'anomalie': {'emotions': array([0, 1, 0, 0, 1, 0]), 'polarity': array([0, 1])},
#  'anonyme': {'emotions': array([0, 1, 1, 0, 0, 1]), 'polarity': array([0, 1])},
#  'anormal': {'emotions': array([0, 1, 0, 1, 1, 1]), 'polarity': array([0, 1])},
#  'anse': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'antagonisme': {'emotions': array([0, 0, 0, 1, 0, 0]),
#                  'polarity': array([0, 1])},
#  'antagoniste': {'emotions': array([0, 1, 0, 1, 0, 1]),
#                  'polarity': array([0, 1])},
#  'antalgique': {'emotions': array([0, 1, 0, 0, 0, 0]),
#                 'polarity': array([0, 1])},
#  'antenne': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'anthologie': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'anthrax': {'emotions': array([0, 1, 1, 0, 0, 1]), 'polarity': array([0, 1])},
#  'anthropologie': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                    'polarity': array([1, 0])},
#  'anthropophage': {'emotions': array([0, 1, 0, 0, 0, 1]),
#                    'polarity': array([0, 1])},
#  'anthropophagie': {'emotions': array([0, 1, 0, 0, 0, 1]),
#                     'polarity': array([0, 1])},
#  'antibiotique': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                   'polarity': array([1, 0])},
#  'anticipatif': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'anticipation': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                   'polarity': array([1, 0])},
#  'anticiper': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
# ...
#  'épuisement': {'emotions': array([0, 1, 1, 0, 0, 0]),
#                 'polarity': array([0, 1])},
#  'épuiser': {'emotions': array([0, 0, 1, 0, 0, 0]), 'polarity': array([0, 1])},
#  'épuration': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'épée': {'emotions': array([0, 1, 0, 0, 0, 0]), 'polarity': array([0, 1])},
#  'épître': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'équateur': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'équation': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'équatorial': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'équerre': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'équestre': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'équidistant': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'équilibration': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                    'polarity': array([1, 0])},
#  'équilibre': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'équilibrer': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'équipage': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'équipement': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'équiper': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'équitable': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'équitablement': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                    'polarity': array([1, 0])},
#  'équitation': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'équité': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'équivalence': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'équivalent': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'équivaloir à': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                   'polarity': array([1, 0])},
#  'équivoque': {'emotions': array([0, 1, 0, 0, 0, 0]),
#                'polarity': array([0, 1])},
#  'éradication': {'emotions': array([0, 1, 1, 1, 0, 1]),
#                  'polarity': array([0, 1])},
#  'éradiquer': {'emotions': array([0, 1, 1, 1, 0, 1]),
#                'polarity': array([0, 1])},
#  'érafler': {'emotions': array([0, 1, 1, 0, 0, 0]), 'polarity': array([0, 1])},
#  'éraflure': {'emotions': array([0, 1, 1, 0, 0, 1]), 'polarity': array([0, 1])},
#  'érection': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'ériger': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'éroder': {'emotions': array([0, 0, 1, 0, 0, 1]), 'polarity': array([0, 1])},
#  'érosion': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([0, 1])},
#  'érotique': {'emotions': array([0, 0, 0, 0, 1, 0]), 'polarity': array([1, 0])},
#  'érudit': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'éruption': {'emotions': array([0, 1, 0, 1, 1, 0]), 'polarity': array([0, 1])},
#  'éruption cutané': {'emotions': array([0, 0, 0, 0, 0, 1]),
#                      'polarity': array([0, 1])},
#  'ésotérique': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'étable': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([0, 1])},
#  'établir': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'établir le fausseté de': {'emotions': array([0, 0, 0, 1, 0, 0]),
#                             'polarity': array([0, 1])},
#  'établir un discrimination': {'emotions': array([0, 0, 1, 1, 0, 1]),
#                                'polarity': array([0, 1])},
#  'établissement': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                    'polarity': array([1, 0])},
#  'établissement scolaire': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                             'polarity': array([1, 0])},
#  'étage': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'étagère': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'étai': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'étain': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'étal': {'emotions': array([0, 0, 0, 0, 0, 1]), 'polarity': array([1, 0])},
#  'étalage': {'emotions': array([1, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'étaler': {'emotions': array([0, 0, 0, 1, 0, 0]), 'polarity': array([0, 1])},
#  'étalon': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'étanche': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'étancher': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'étang': {'emotions': array([0, 0, 0, 0, 0, 1]), 'polarity': array([0, 1])},
#  'étape': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'étape important': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                      'polarity': array([1, 0])},
#  'état': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'étau': {'emotions': array([0, 1, 0, 0, 0, 0]), 'polarity': array([0, 1])},
#  'étayer': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'éteindre': {'emotions': array([0, 0, 1, 1, 0, 0]), 'polarity': array([0, 1])},
#  'étendre': {'emotions': array([0, 1, 1, 1, 0, 1]), 'polarity': array([0, 1])},
#  'étendue sauvage': {'emotions': array([0, 1, 1, 0, 0, 0]),
#                      'polarity': array([0, 1])},
#  'éternel': {'emotions': array([0, 0, 1, 0, 0, 0]), 'polarity': array([1, 0])},
#  'éternité': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'éternuement': {'emotions': array([0, 0, 0, 0, 1, 1]),
#                  'polarity': array([0, 1])},
#  'éternuer': {'emotions': array([0, 0, 0, 0, 1, 0]), 'polarity': array([0, 1])},
#  'éthanol': {'emotions': array([0, 0, 0, 0, 0, 1]), 'polarity': array([0, 1])},
#  'éther': {'emotions': array([0, 0, 0, 0, 0, 1]), 'polarity': array([0, 1])},
#  'éthique': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'éthéré': {'emotions': array([0, 1, 0, 0, 0, 0]), 'polarity': array([0, 1])},
#  'étincelant': {'emotions': array([1, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'étinceler': {'emotions': array([1, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'étincell': {'emotions': array([0, 0, 0, 0, 1, 0]), 'polarity': array([1, 0])},
#  'étiologie': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'étiqueter': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'étiquette': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'étirer': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'étoffe': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'étoile': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'étoiler': {'emotions': array([1, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'étole': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'étonnamment': {'emotions': array([0, 0, 0, 0, 1, 0]),
#                  'polarity': array([1, 0])},
#  'étonnant': {'emotions': array([0, 0, 0, 0, 1, 0]), 'polarity': array([1, 0])},
#  'étonnement': {'emotions': array([0, 1, 0, 0, 1, 0]),
#                 'polarity': array([1, 0])},
#  'étonner': {'emotions': array([0, 1, 0, 0, 1, 0]), 'polarity': array([1, 0])},
#  'étouffant': {'emotions': array([0, 1, 1, 0, 0, 1]),
#                'polarity': array([0, 1])},
#  'étouffer': {'emotions': array([0, 1, 1, 1, 1, 1]), 'polarity': array([0, 1])},
#  'étouffoir': {'emotions': array([0, 1, 0, 0, 0, 0]),
#                'polarity': array([0, 1])},
#  'étourderie': {'emotions': array([0, 1, 1, 0, 0, 0]),
#                 'polarity': array([0, 1])},
#  'étourdir': {'emotions': array([0, 1, 1, 0, 1, 0]), 'polarity': array([0, 1])},
#  'étourdissement': {'emotions': array([0, 1, 0, 0, 1, 0]),
#                     'polarity': array([0, 1])},
#  'étrange': {'emotions': array([0, 1, 0, 0, 1, 1]), 'polarity': array([0, 1])},
#  'étrangement': {'emotions': array([0, 1, 0, 0, 1, 0]),
#                  'polarity': array([0, 1])},
#  'étranger': {'emotions': array([0, 1, 1, 0, 0, 1]), 'polarity': array([0, 1])},
#  'étrangeté': {'emotions': array([0, 0, 1, 0, 1, 1]),
#                'polarity': array([0, 1])},
#  'étrangleur': {'emotions': array([0, 1, 1, 1, 1, 0]),
#                 'polarity': array([0, 1])},
#  'étreindre': {'emotions': array([0, 0, 0, 0, 1, 0]),
#                'polarity': array([1, 0])},
#  'étreinte': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'étriquer': {'emotions': array([0, 1, 1, 0, 0, 0]), 'polarity': array([0, 1])},
#  'étroit': {'emotions': array([0, 1, 1, 0, 0, 0]), 'polarity': array([0, 1])},
#  'étroitess': {'emotions': array([0, 1, 1, 1, 0, 0]),
#                'polarity': array([0, 1])},
#  'étude': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'étudiant': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'étudier': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'étudier de deuxième année': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                                'polarity': array([1, 0])},
#  'étudier de premier année': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                               'polarity': array([1, 0])},
#  'étudier de premier cycle unir': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                                    'polarity': array([1, 0])},
#  'étymologie': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'évacuation': {'emotions': array([0, 1, 0, 0, 0, 0]),
#                 'polarity': array([0, 1])},
#  'évader': {'emotions': array([0, 1, 0, 1, 0, 0]), 'polarity': array([0, 1])},
#  'évaluer': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'évanescence': {'emotions': array([0, 0, 1, 0, 1, 0]),
#                  'polarity': array([0, 1])},
#  'évangil': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'évangélique': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'évangéliste': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'évanouissement': {'emotions': array([0, 1, 1, 0, 1, 0]),
#                     'polarity': array([0, 1])},
#  'évaporation': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([0, 1])},
#  'évasif': {'emotions': array([0, 0, 0, 0, 1, 0]), 'polarity': array([0, 1])},
#  'éveil': {'emotions': array([1, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'éveiller': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'évent': {'emotions': array([0, 0, 0, 1, 0, 0]), 'polarity': array([1, 0])},
#  'éventail': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'éventer': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'éventuel': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([0, 1])},
#  'éventuellement': {'emotions': array([0, 0, 0, 0, 1, 0]),
#                     'polarity': array([1, 0])},
#  'évidemment': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                 'polarity': array([1, 0])},
#  'évident': {'emotions': array([0, 0, 0, 1, 0, 1]), 'polarity': array([1, 0])},
#  'évier': {'emotions': array([0, 1, 1, 0, 0, 0]), 'polarity': array([0, 1])},
#  'évincer': {'emotions': array([0, 1, 1, 1, 1, 0]), 'polarity': array([0, 1])},
#  'évitement': {'emotions': array([0, 0, 0, 0, 0, 1]),
#                'polarity': array([0, 1])},
#  'éviter': {'emotions': array([0, 1, 0, 0, 0, 1]), 'polarity': array([0, 1])},
#  'évocateur': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'évoluer': {'emotions': array([1, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'évolution': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                'polarity': array([1, 0])},
#  'évoquer': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'événement': {'emotions': array([0, 0, 0, 0, 1, 0]),
#                'polarity': array([1, 0])},
#  'événement fortuit': {'emotions': array([0, 0, 0, 0, 1, 0]),
#                        'polarity': array([1, 0])},
#  'événement marquer': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                        'polarity': array([1, 0])},
#  'évêque': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'être': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'être affaler': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                   'polarity': array([0, 1])},
#  'être allonger': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                    'polarity': array([1, 0])},
#  'être apprenti': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                    'polarity': array([1, 0])},
#  'être assortir': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                    'polarity': array([1, 0])},
#  'être au service de': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                         'polarity': array([0, 1])},
#  'être avachir': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                   'polarity': array([0, 1])},
#  'être bénéfique': {'emotions': array([1, 0, 0, 0, 0, 0]),
#                     'polarity': array([1, 0])},
#  'être bénévole': {'emotions': array([0, 1, 0, 0, 0, 0]),
#                    'polarity': array([1, 0])},
#  'être caractériser': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                        'polarity': array([1, 0])},
#  'être conforme à': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                      'polarity': array([1, 0])},
#  'être constamment sur le dos de': {'emotions': array([0, 1, 1, 1, 0, 0]),
#                                     'polarity': array([0, 1])},
#  'être domicilier': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                      'polarity': array([1, 0])},
#  'être en adéquation': {'emotions': array([0, 1, 0, 1, 0, 0]),
#                         'polarity': array([0, 1])},
#  'être en apprentissage': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                            'polarity': array([1, 0])},
#  'être en désaccord': {'emotions': array([0, 0, 0, 1, 0, 0]),
#                        'polarity': array([0, 1])},
#  'être en rage': {'emotions': array([0, 0, 0, 1, 0, 0]),
#                   'polarity': array([0, 1])},
#  'être imposer': {'emotions': array([0, 1, 0, 1, 0, 1]),
#                   'polarity': array([0, 1])},
#  'être incliner': {'emotions': array([0, 1, 0, 0, 0, 0]),
#                    'polarity': array([0, 1])},
#  'être indiscret': {'emotions': array([0, 0, 0, 1, 0, 1]),
#                     'polarity': array([0, 1])},
#  'être inonder': {'emotions': array([0, 1, 0, 0, 0, 0]),
#                   'polarity': array([0, 1])},
#  'être le plus toucher par': {'emotions': array([0, 0, 1, 1, 0, 0]),
#                               'polarity': array([0, 1])},
#  'être le premier toucher par': {'emotions': array([0, 0, 1, 1, 0, 0]),
#                                  'polarity': array([0, 1])},
#  'être protubérant': {'emotions': array([0, 1, 0, 0, 0, 1]),
#                       'polarity': array([0, 1])},
#  'être quitte': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                  'polarity': array([1, 0])},
#  'être rayonner': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                    'polarity': array([1, 0])},
#  'être souffrir': {'emotions': array([0, 0, 1, 0, 0, 0]),
#                    'polarity': array([0, 1])},
#  'être à le traîne': {'emotions': array([0, 0, 1, 0, 0, 0]),
#                       'polarity': array([0, 1])},
#  'être à le tête': {'emotions': array([0, 0, 0, 0, 0, 0]),
#                     'polarity': array([1, 0])},
#  'île': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'îlot': {'emotions': array([0, 0, 0, 0, 0, 0]), 'polarity': array([1, 0])},
#  'ôter': {'emotions': array([0, 1, 1, 1, 0, 0]), 'polarity': array([0, 1])}}

# %%
import csv
import numpy as np

lemma_path = "./lexique/emotion_dictionary_lemmatized.csv"
final_path = "./lexique/emotion_dictionary_final.csv"

def process_duplicates(duplicates):
    words_to_remove = set()
    processed_duplicates = {}
    for word, info in duplicates.items():
        if len(info) > 1:  # Doublon, nous devons gérer la fusion
            polarities = np.array([info[i]['polarity'] for i in range(len(info))])
            if np.all(polarities == polarities[0]):
                # Toutes les polarités sont identiques, prenons en compte tous les "1" pour les émotions
                max_emotions = np.maximum.reduce([info[i]['emotions'] for i in range(len(info))])
                info = [{'polarity': polarities[0], 'emotions': max_emotions}]
            else:
                # Les polarités sont différentes, nous devons supprimer le mot
                words_to_remove.add(word)
        else:
            max_emotions = np.maximum.reduce([info[i]['emotions'] for i in range(len(info))])
            info = [{'polarity': info[0]['polarity'], 'emotions': max_emotions}]
        processed_duplicates[word] = info

    return words_to_remove, processed_duplicates


def write_final_dictionary(emotion_dict_path, output_file):
    duplicates = {}
    with open(emotion_dict_path, newline='', encoding='utf-8') as csv_file:
        csv_reader = csv.DictReader(csv_file, delimiter=';')
        for row in csv_reader:
            word = row['word']
            polarity = np.array([int(row['positive']), int(row['negative'])])
            emotions = np.array([int(row['joy']), int(row['fear']), int(row['sadness']),
                                 int(row['anger']), int(row['surprise']), int(row['disgust'])])

            if word in duplicates:
                duplicates[word].append({'polarity': polarity, 'emotions': emotions})
            else:
                duplicates[word] = [{'polarity': polarity, 'emotions': emotions}]

    # Gérer les doublons et récupérer les informations traitées
    words_to_remove, processed_duplicates = process_duplicates(duplicates)

    # Créer le dictionnaire final sans les doublons
    emotion_dict_lemmatized = {}
    for word, info in processed_duplicates.items():
        if word not in words_to_remove:
            # Prendre la première valeur de polarité et d'émotions
            polarity = info[0]['polarity']
            emotions = info[0]['emotions']
            emotion_dict_lemmatized[word] = {'polarity': polarity, 'emotions': emotions}

    # Écrire le dictionnaire d'émotions lemmatisé dans un fichier de sortie
    with open(output_file, 'w', newline='', encoding='utf-8') as outfile:
        fieldnames = ['word', 'positive', 'negative', 'joy', 'fear', 'sadness', 'anger', 'surprise', 'disgust']
        csv_writer = csv.DictWriter(outfile, delimiter=';', fieldnames=fieldnames)
        csv_writer.writeheader()

        for word, emotions in emotion_dict_lemmatized.items():
            row = {
                'word': word,
                'positive': emotions['polarity'][0],
                'negative': emotions['polarity'][1],
                'joy': emotions['emotions'][0],
                'fear': emotions['emotions'][1],
                'sadness': emotions['emotions'][2],
                'anger': emotions['emotions'][3],
                'surprise': emotions['emotions'][4],
                'disgust': emotions['emotions'][5]
            }
            csv_writer.writerow(row)

# Appel de la fonction pour créer le dictionnaire final
write_final_dictionary(lemma_path, final_path)

# %%
polarity_path = "./lexique/emotion_dictionary.csv"
clean_path = "./lexique/emotion_dictionary_clean.csv"
manual_path = "./lexique/emotion_dictionary_clean_manual.csv"
lemma_path = "./lexique/emotion_dictionary_lemmatized.csv"
final_path = "./lexique/emotion_dictionary_final.csv"

# Comptage des lignes du CSV
csv_polarity = load_csv_content(polarity_path)
csv_clean = load_csv_content(clean_path)
csv_manual = load_csv_content(manual_path)
csv_lemma = load_csv_content(lemma_path)
csv_final = load_csv_content(final_path)

num_csv_polarity = len(csv_polarity)
num_csv_clean = len(csv_clean)
num_csv_manual = len(csv_manual)
num_csv_lemma = len(csv_lemma)
num_csv_final = len(csv_final)

# Comptage des clés du dictionnaire
dict_polarity = load_dictionary(polarity_path) 
dict_clean = load_dictionary(clean_path)
dict_manual = load_dictionary(manual_path)
dict_lemma = load_dictionary(lemma_path)
dict_final = load_dictionary(final_path)

num_dict_polarity = len(dict_polarity)
num_dict_clean = len(dict_clean)
num_dict_manual = len(dict_manual)
num_dict_lemma = len(dict_lemma)
num_dict_final = len(dict_final)

print("Nombre de lignes (sans les en-têtes) :")
print("---------------------")
print(f"CSV - Gestion des polarités : {num_csv_polarity}")
print(f"CSV - Nettoyage automatique : {num_csv_clean}")
print(f"CSV - Nettoyage manuel : {num_csv_manual}")
print(f"CSV - Lemmatisation spaCy : {num_csv_lemma}")
print(f"CSV - Gestion des doublons : {num_csv_final}")
print("---------------------")
print(f"Dictionnaire - Gestion des polarités : {num_dict_polarity}")
print(f"Dictionnaire - Nettoyage automatique : {num_dict_clean}")
print(f"Dictionnaire - Nettoyage manuel : {num_dict_manual}")
print(f"Dictionnaire - Lemmatisation spaCy : {num_dict_lemma}")
print(f"Dictionnaire - Gestion des doublons : {num_dict_final}")
# Out:
# Nombre de lignes (sans les en-têtes) :
# ---------------------
# CSV - Gestion des polarités : 14127
# CSV - Nettoyage automatique : 14127
# CSV - Nettoyage manuel : 14127
# CSV - Lemmatisation spaCy : 14125
# CSV - Gestion des doublons : 13624
# ---------------------
# Dictionnaire - Gestion des polarités : 14126
# Dictionnaire - Nettoyage automatique : 14110
# Dictionnaire - Nettoyage manuel : 14072
# Dictionnaire - Lemmatisation spaCy : 13658
# Dictionnaire - Gestion des doublons : 13624

# %%
# Trouver les doublons dans le dictionnaire
duplicates = find_duplicates(csv_final)

# Imprimer les doublons et leurs vecteurs correspondants
for word, values in duplicates.items():
    if len(values['polarity']) > 1:
        print("---------------------")
        print("'" + word + "'")
        print("---------------------")
        for i in range(len(values['polarity'])):
            print("Polarité :", values['polarity'][i])
            print("Vecteur d'émotions :", values['emotions'][i])

# %% [markdown]
# #### Matrice de la distribution des termes à l'intérieur des catégories

# %%
# Charger les données à partir du fichier CSV dans un DataFrame
df = pd.read_csv("./lexique/emotion_dictionary_final.csv", delimiter=";", index_col=0)

df.head(10)
# Out:
#                   positive  negative  joy  fear  sadness  anger  surprise  \
# word
# @card@ kilo              1         0    0     0        0      0         0
# à base de plante         1         0    0     0        0      0         0
# à bord                   1         0    0     0        0      0         0
# à capuche                1         0    0     1        0      0         0
# à carreau                1         0    0     0        0      0         0
# à ce endroit -là         1         0    0     0        0      0         0
# à clou                   0         1    0     0        0      0         0
# à condition que          1         0    0     0        0      0         0
# à contrecoeur            0         1    0     1        1      1         0
# à côte                   0         1    0     0        0      0         0
#
#                   disgust
# word
# @card@ kilo             0
# à base de plante        0
# à bord                  0
# à capuche               0
# à carreau               0
# à ce endroit -là        0
# à clou                  0
# à condition que         0
# à contrecoeur           1
# à côte                  1

# %%
import pandas as pd

# Charger les données à partir du fichier CSV dans un DataFrame
df = pd.read_csv("./lexique/emotion_dictionary_final.csv", delimiter=";")

# Sélectionner les colonnes d'intérêt pour les émotions en utilisant l'index numérique
emotions_df = df.iloc[:, 1:]  # Ici, nous supposons que les colonnes d'intérêt commencent à l'index 1 (positivity) jusqu'à la fin

# Créer une matrice 8x8 remplie de zéros
matrix = pd.DataFrame(0, index=emotions_df.columns, columns=emotions_df.columns)

# Parcourir les termes et mettre à jour la matrice avec les occurrences des paires émotion-polarité
for term, row in emotions_df.iterrows():
    for emotion1 in emotions_df.columns:
        if row[emotion1] != 0:
            for emotion2 in emotions_df.columns:
                if row[emotion2] != 0:
                    matrix.loc[emotion1, emotion2] += 1

# Affichage de la matrice
display(matrix)
# Out:
#           positive  negative  joy  fear  sadness  anger  surprise  disgust
# positive      8156         0  498   214      124    117       425       91
# negative         0      5468    7  2862     2286   1919       723     1858
# joy            498         7  505     3        0      0         6        0
# fear           214      2862    3  3076     1489   1292       634      889
# sadness        124      2286    0  1489     2410    907       286      811
# anger          117      1919    0  1292      907   2036       351      860
# surprise       425       723    6   634      286    351      1148      135
# disgust         91      1858    0   889      811    860       135     1949
